# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.DenseNet121(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 375s 2s/step - accuracy: 0.6695 - loss: 0.9495 - val_accuracy: 0.8512 - val_loss: 0.4298
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 344s 2s/step - accuracy: 0.8991 - loss: 0.3038 - val_accuracy: 0.8780 - val_loss: 0.3417
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 339s 2s/step - accuracy: 0.9220 - loss: 0.2137 - val_accuracy: 0.8988 - val_loss: 0.2894
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 337s 2s/step - accuracy: 0.9571 - loss: 0.1350 - val_accuracy: 0.9271 - val_loss: 0.2169
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 337s 2s/step - accuracy: 0.9692 - loss: 0.0976 - val_accuracy: 0.9271 - val_loss: 0.1871
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 395s 2s/step - accuracy: 0.9810 - loss: 0.0691 - val_accuracy: 0.9315 - val_loss: 0.2036
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 363s 2s/step - accuracy: 0.9878 - loss: 0.0420 - val_accuracy: 0.9390 - val_loss: 0.1980
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 375s 2s/step - accuracy: 0.9864 - loss: 0.0502 - val_accuracy: 0.9048 - val_loss: 0.3055
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 373s 2s/step - accuracy: 0.9857 - loss: 0.0461 - val_accuracy: 0.9301 - val_loss: 0.2317
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 382s 2s/step - accuracy: 0.9922 - loss: 0.0298 - val_accuracy: 0.9211 - val_loss: 0.2367
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 387s 2s/step - accuracy: 0.9886 - loss: 0.0381 - val_accuracy: 0.9464 - val_loss: 0.1702
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 300s 2s/step - accuracy: 0.9962 - loss: 0.0161 - val_accuracy: 0.9449 - val_loss: 0.2064
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 286s 2s/step - accuracy: 0.9963 - loss: 0.0124 - val_accuracy: 0.9048 - val_loss: 0.2582
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 280s 2s/step - accuracy: 0.9796 - loss: 0.0640 - val_accuracy: 0.9241 - val_loss: 0.2835
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 279s 2s/step - accuracy: 0.9872 - loss: 0.0398 - val_accuracy: 0.9345 - val_loss: 0.2174
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 278s 2s/step - accuracy: 0.9980 - loss: 0.0118 - val_accuracy: 0.9464 - val_loss: 0.1937
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 281s 2s/step - accuracy: 0.9988 - loss: 0.0049 - val_accuracy: 0.9479 - val_loss: 0.2131
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 279s 2s/step - accuracy: 0.9992 - loss: 0.0035 - val_accuracy: 0.9449 - val_loss: 0.1750
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 277s 2s/step - accuracy: 0.9953 - loss: 0.0120 - val_accuracy: 0.9435 - val_loss: 0.2020
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 276s 2s/step - accuracy: 0.9943 - loss: 0.0184 - val_accuracy: 0.9003 - val_loss: 0.4367
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 265s 2s/step - accuracy: 0.9684 - loss: 0.0900 - val_accuracy: 0.9435 - val_loss: 0.2194
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.9873 - loss: 0.0378 - val_accuracy: 0.9286 - val_loss: 0.3268
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 294s 2s/step - accuracy: 0.9931 - loss: 0.0202 - val_accuracy: 0.9345 - val_loss: 0.3029
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 276s 2s/step - accuracy: 0.9938 - loss: 0.0187 - val_accuracy: 0.9390 - val_loss: 0.2595
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 257s 1s/step - accuracy: 0.9922 - loss: 0.0215 - val_accuracy: 0.9494 - val_loss: 0.2332
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9524 - val_loss: 0.2134
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 232s 1s/step - accuracy: 1.0000 - loss: 5.4044e-04 - val_accuracy: 0.9509 - val_loss: 0.2144
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 241s 1s/step - accuracy: 1.0000 - loss: 3.5201e-04 - val_accuracy: 0.9509 - val_loss: 0.2217
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 240s 1s/step - accuracy: 1.0000 - loss: 3.4598e-04 - val_accuracy: 0.9509 - val_loss: 0.2139
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 242s 1s/step - accuracy: 1.0000 - loss: 2.5068e-04 - val_accuracy: 0.9509 - val_loss: 0.2176
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 244s 1s/step - accuracy: 1.0000 - loss: 2.3395e-04 - val_accuracy: 0.9509 - val_loss: 0.2211
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 242s 1s/step - accuracy: 1.0000 - loss: 2.1670e-04 - val_accuracy: 0.9509 - val_loss: 0.2185
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 258s 1s/step - accuracy: 1.0000 - loss: 1.8337e-04 - val_accuracy: 0.9509 - val_loss: 0.2227
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 266s 2s/step - accuracy: 1.0000 - loss: 1.8583e-04 - val_accuracy: 0.9509 - val_loss: 0.2176
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - accuracy: 1.0000 - loss: 1.5459e-04 - val_accuracy: 0.9524 - val_loss: 0.2160
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 269s 2s/step - accuracy: 1.0000 - loss: 1.5853e-04 - val_accuracy: 0.9524 - val_loss: 0.2234
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - accuracy: 1.0000 - loss: 1.4311e-04 - val_accuracy: 0.9509 - val_loss: 0.2255
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 269s 2s/step - accuracy: 1.0000 - loss: 1.3384e-04 - val_accuracy: 0.9524 - val_loss: 0.2226
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - accuracy: 1.0000 - loss: 1.2333e-04 - val_accuracy: 0.9524 - val_loss: 0.2229
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 284s 2s/step - accuracy: 1.0000 - loss: 1.0390e-04 - val_accuracy: 0.9524 - val_loss: 0.2283
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 258s 1s/step - accuracy: 1.0000 - loss: 9.5347e-05 - val_accuracy: 0.9524 - val_loss: 0.2278
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 265s 2s/step - accuracy: 1.0000 - loss: 9.8368e-05 - val_accuracy: 0.9524 - val_loss: 0.2307
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 264s 2s/step - accuracy: 1.0000 - loss: 7.9289e-05 - val_accuracy: 0.9524 - val_loss: 0.2413
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 1.0000 - loss: 9.7925e-05 - val_accuracy: 0.9524 - val_loss: 0.2284
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 1.0000 - loss: 6.8133e-05 - val_accuracy: 0.9524 - val_loss: 0.2303
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 259s 1s/step - accuracy: 1.0000 - loss: 6.4421e-05 - val_accuracy: 0.9554 - val_loss: 0.2288
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 1.0000 - loss: 6.1172e-05 - val_accuracy: 0.9524 - val_loss: 0.2330
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 1.0000 - loss: 5.5452e-05 - val_accuracy: 0.9524 - val_loss: 0.2328
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 265s 2s/step - accuracy: 1.0000 - loss: 5.4282e-05 - val_accuracy: 0.9539 - val_loss: 0.2323
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 265s 2s/step - accuracy: 1.0000 - loss: 5.4283e-05 - val_accuracy: 0.9524 - val_loss: 0.2345

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 95.24%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'DenseNet121_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.9682 - loss: 0.1453
# Test Accuracy: 94.57%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       0.99      0.99      0.99       100
#              Chickenpox       0.89      0.99      0.94       100
#                  Cowpox       0.99      0.96      0.97       100
#                    HFMD       0.92      0.88      0.90       100
#                 Healthy       0.95      0.95      0.95       100
#                 Measles       0.96      0.99      0.98       100
#               Monkeypox       0.92      0.86      0.89       100
#
#                accuracy                           0.95       700
#               macro avg       0.95      0.95      0.95       700
#            weighted avg       0.95      0.95      0.95       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.ResNet50V2(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# Epoch 1/50
# c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 356s 2s/step - accuracy: 0.7004 - loss: 0.9607 - val_accuracy: 0.8958 - val_loss: 0.2901
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 336s 2s/step - accuracy: 0.9461 - loss: 0.1619 - val_accuracy: 0.9107 - val_loss: 0.2336
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - accuracy: 0.9714 - loss: 0.0875 - val_accuracy: 0.9122 - val_loss: 0.2530
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 492s 3s/step - accuracy: 0.9887 - loss: 0.0368 - val_accuracy: 0.9137 - val_loss: 0.3259
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 219s 1s/step - accuracy: 0.9928 - loss: 0.0283 - val_accuracy: 0.9315 - val_loss: 0.2297
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9983 - loss: 0.0149 - val_accuracy: 0.9375 - val_loss: 0.1872
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.9999 - loss: 0.0030 - val_accuracy: 0.9330 - val_loss: 0.1927
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 0.9375 - val_loss: 0.1875
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9405 - val_loss: 0.1945
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 1.0000 - loss: 6.5587e-04 - val_accuracy: 0.9390 - val_loss: 0.1998
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 1.0000 - loss: 5.1331e-04 - val_accuracy: 0.9435 - val_loss: 0.2000
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 1.0000 - loss: 4.1945e-04 - val_accuracy: 0.9390 - val_loss: 0.2014
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 1.0000 - loss: 3.4864e-04 - val_accuracy: 0.9390 - val_loss: 0.2017
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 228s 1s/step - accuracy: 1.0000 - loss: 2.9853e-04 - val_accuracy: 0.9405 - val_loss: 0.2053
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 236s 1s/step - accuracy: 1.0000 - loss: 2.5993e-04 - val_accuracy: 0.9405 - val_loss: 0.2063
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 1.0000 - loss: 2.3107e-04 - val_accuracy: 0.9405 - val_loss: 0.2048
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 246s 1s/step - accuracy: 1.0000 - loss: 2.1044e-04 - val_accuracy: 0.9420 - val_loss: 0.2095
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 237s 1s/step - accuracy: 1.0000 - loss: 1.8742e-04 - val_accuracy: 0.9405 - val_loss: 0.2098
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 220s 1s/step - accuracy: 1.0000 - loss: 1.6354e-04 - val_accuracy: 0.9405 - val_loss: 0.2123
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 214s 1s/step - accuracy: 1.0000 - loss: 1.4694e-04 - val_accuracy: 0.9420 - val_loss: 0.2135
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - accuracy: 1.0000 - loss: 1.3132e-04 - val_accuracy: 0.9405 - val_loss: 0.2140
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 1.0000 - loss: 1.2529e-04 - val_accuracy: 0.9435 - val_loss: 0.2148
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 209s 1s/step - accuracy: 1.0000 - loss: 1.0452e-04 - val_accuracy: 0.9405 - val_loss: 0.2174
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 207s 1s/step - accuracy: 1.0000 - loss: 1.0025e-04 - val_accuracy: 0.9405 - val_loss: 0.2155
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 337s 2s/step - accuracy: 1.0000 - loss: 8.7513e-05 - val_accuracy: 0.9405 - val_loss: 0.2172
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 340s 2s/step - accuracy: 1.0000 - loss: 7.4844e-05 - val_accuracy: 0.9390 - val_loss: 0.2184
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3976s 23s/step - accuracy: 1.0000 - loss: 6.9621e-05 - val_accuracy: 0.9405 - val_loss: 0.2214
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 168s 959ms/step - accuracy: 1.0000 - loss: 6.2050e-05 - val_accuracy: 0.9420 - val_loss: 0.2194
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 1.0000 - loss: 5.5203e-05 - val_accuracy: 0.9405 - val_loss: 0.2229
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 1.0000 - loss: 5.2017e-05 - val_accuracy: 0.9405 - val_loss: 0.2222
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 1.0000 - loss: 4.2310e-05 - val_accuracy: 0.9405 - val_loss: 0.2245
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 237s 1s/step - accuracy: 1.0000 - loss: 4.0675e-05 - val_accuracy: 0.9435 - val_loss: 0.2247
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 242s 1s/step - accuracy: 1.0000 - loss: 3.8991e-05 - val_accuracy: 0.9405 - val_loss: 0.2272
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 277s 2s/step - accuracy: 1.0000 - loss: 3.5101e-05 - val_accuracy: 0.9435 - val_loss: 0.2268
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 3.0554e-05 - val_accuracy: 0.9405 - val_loss: 0.2295
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 1.0000 - loss: 2.9189e-05 - val_accuracy: 0.9420 - val_loss: 0.2289
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 1.0000 - loss: 2.5101e-05 - val_accuracy: 0.9405 - val_loss: 0.2325
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 1.0000 - loss: 2.2634e-05 - val_accuracy: 0.9405 - val_loss: 0.2302
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 229s 1s/step - accuracy: 1.0000 - loss: 2.1450e-05 - val_accuracy: 0.9405 - val_loss: 0.2291
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 229s 1s/step - accuracy: 1.0000 - loss: 1.9237e-05 - val_accuracy: 0.9405 - val_loss: 0.2348
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 237s 1s/step - accuracy: 1.0000 - loss: 1.7525e-05 - val_accuracy: 0.9405 - val_loss: 0.2355
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 1.0000 - loss: 1.5177e-05 - val_accuracy: 0.9405 - val_loss: 0.2363
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 1.0000 - loss: 1.4007e-05 - val_accuracy: 0.9420 - val_loss: 0.2376
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 236s 1s/step - accuracy: 1.0000 - loss: 1.3267e-05 - val_accuracy: 0.9405 - val_loss: 0.2364
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 1.0000 - loss: 1.1313e-05 - val_accuracy: 0.9405 - val_loss: 0.2395
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - accuracy: 1.0000 - loss: 1.0237e-05 - val_accuracy: 0.9405 - val_loss: 0.2383
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 1.0000 - loss: 9.6078e-06 - val_accuracy: 0.9405 - val_loss: 0.2414
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - accuracy: 1.0000 - loss: 9.7850e-06 - val_accuracy: 0.9405 - val_loss: 0.2428
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - accuracy: 1.0000 - loss: 8.1858e-06 - val_accuracy: 0.9405 - val_loss: 0.2457
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 229s 1s/step - accuracy: 1.0000 - loss: 7.3910e-06 - val_accuracy: 0.9420 - val_loss: 0.2450

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 94.20%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'ResNet50V2_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.9657 - loss: 0.1572
# Test Accuracy: 94.43%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       1.00      1.00      1.00       100
#              Chickenpox       0.88      0.94      0.91       100
#                  Cowpox       0.97      0.96      0.96       100
#                    HFMD       0.93      0.92      0.92       100
#                 Healthy       0.93      0.98      0.96       100
#                 Measles       0.96      0.94      0.95       100
#               Monkeypox       0.95      0.87      0.91       100
#
#                accuracy                           0.94       700
#               macro avg       0.95      0.94      0.94       700
#            weighted avg       0.95      0.94      0.94       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

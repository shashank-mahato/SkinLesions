# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.MobileNet(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 70s 388ms/step - accuracy: 0.6795 - loss: 0.9927 - val_accuracy: 0.8735 - val_loss: 0.3433
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 73s 420ms/step - accuracy: 0.9159 - loss: 0.2378 - val_accuracy: 0.9092 - val_loss: 0.2726
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 70s 398ms/step - accuracy: 0.9574 - loss: 0.1318 - val_accuracy: 0.9241 - val_loss: 0.2351
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 70s 400ms/step - accuracy: 0.9818 - loss: 0.0706 - val_accuracy: 0.9182 - val_loss: 0.2279
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 71s 408ms/step - accuracy: 0.9886 - loss: 0.0445 - val_accuracy: 0.9211 - val_loss: 0.2321
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 75s 427ms/step - accuracy: 0.9916 - loss: 0.0346 - val_accuracy: 0.9256 - val_loss: 0.2066
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 69s 396ms/step - accuracy: 0.9958 - loss: 0.0195 - val_accuracy: 0.9390 - val_loss: 0.1774
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 75s 431ms/step - accuracy: 0.9990 - loss: 0.0089 - val_accuracy: 0.9390 - val_loss: 0.1925
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 71s 405ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9360 - val_loss: 0.2070
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 70s 399ms/step - accuracy: 0.9996 - loss: 0.0034 - val_accuracy: 0.9420 - val_loss: 0.1992
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 72s 409ms/step - accuracy: 0.9998 - loss: 0.0031 - val_accuracy: 0.9420 - val_loss: 0.2133
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 71s 406ms/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 0.9405 - val_loss: 0.2142
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 66s 379ms/step - accuracy: 0.9993 - loss: 0.0033 - val_accuracy: 0.9360 - val_loss: 0.2067
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 69s 393ms/step - accuracy: 0.9855 - loss: 0.0495 - val_accuracy: 0.8021 - val_loss: 0.8630
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 71s 404ms/step - accuracy: 0.9383 - loss: 0.1854 - val_accuracy: 0.9271 - val_loss: 0.2571
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 68s 388ms/step - accuracy: 0.9783 - loss: 0.0631 - val_accuracy: 0.9405 - val_loss: 0.2589
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 383ms/step - accuracy: 0.9973 - loss: 0.0103 - val_accuracy: 0.9345 - val_loss: 0.2623
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 66s 375ms/step - accuracy: 0.9985 - loss: 0.0071 - val_accuracy: 0.9405 - val_loss: 0.2362
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 66s 375ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9479 - val_loss: 0.2407
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 65s 371ms/step - accuracy: 1.0000 - loss: 8.5326e-04 - val_accuracy: 0.9464 - val_loss: 0.2442
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 383ms/step - accuracy: 1.0000 - loss: 5.3464e-04 - val_accuracy: 0.9464 - val_loss: 0.2464
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 65s 373ms/step - accuracy: 1.0000 - loss: 4.9714e-04 - val_accuracy: 0.9449 - val_loss: 0.2503
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 65s 370ms/step - accuracy: 1.0000 - loss: 3.5513e-04 - val_accuracy: 0.9449 - val_loss: 0.2553
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 64s 364ms/step - accuracy: 1.0000 - loss: 3.0506e-04 - val_accuracy: 0.9449 - val_loss: 0.2571
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 65s 369ms/step - accuracy: 1.0000 - loss: 2.8943e-04 - val_accuracy: 0.9464 - val_loss: 0.2557
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 61s 347ms/step - accuracy: 1.0000 - loss: 2.5897e-04 - val_accuracy: 0.9449 - val_loss: 0.2609
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 63s 358ms/step - accuracy: 1.0000 - loss: 2.3011e-04 - val_accuracy: 0.9509 - val_loss: 0.2568
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 56s 320ms/step - accuracy: 1.0000 - loss: 2.0211e-04 - val_accuracy: 0.9464 - val_loss: 0.2652
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 59s 339ms/step - accuracy: 1.0000 - loss: 1.9254e-04 - val_accuracy: 0.9479 - val_loss: 0.2667
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 61s 349ms/step - accuracy: 1.0000 - loss: 1.7874e-04 - val_accuracy: 0.9464 - val_loss: 0.2693
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 59s 340ms/step - accuracy: 1.0000 - loss: 1.3768e-04 - val_accuracy: 0.9479 - val_loss: 0.2688
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 55s 316ms/step - accuracy: 1.0000 - loss: 1.3263e-04 - val_accuracy: 0.9449 - val_loss: 0.2767
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 55s 316ms/step - accuracy: 1.0000 - loss: 1.3121e-04 - val_accuracy: 0.9464 - val_loss: 0.2697
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 55s 315ms/step - accuracy: 1.0000 - loss: 1.1406e-04 - val_accuracy: 0.9494 - val_loss: 0.2715
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 59s 336ms/step - accuracy: 1.0000 - loss: 1.1320e-04 - val_accuracy: 0.9449 - val_loss: 0.2753
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 60s 344ms/step - accuracy: 1.0000 - loss: 9.0395e-05 - val_accuracy: 0.9449 - val_loss: 0.2807
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 57s 328ms/step - accuracy: 1.0000 - loss: 9.6782e-05 - val_accuracy: 0.9479 - val_loss: 0.2791
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 56s 320ms/step - accuracy: 1.0000 - loss: 7.7975e-05 - val_accuracy: 0.9479 - val_loss: 0.2815
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 59s 337ms/step - accuracy: 1.0000 - loss: 7.6696e-05 - val_accuracy: 0.9479 - val_loss: 0.2837
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 60s 344ms/step - accuracy: 1.0000 - loss: 6.2113e-05 - val_accuracy: 0.9449 - val_loss: 0.2893
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 58s 332ms/step - accuracy: 1.0000 - loss: 6.1182e-05 - val_accuracy: 0.9479 - val_loss: 0.2929
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 63s 359ms/step - accuracy: 1.0000 - loss: 6.2312e-05 - val_accuracy: 0.9509 - val_loss: 0.2832
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 64s 368ms/step - accuracy: 1.0000 - loss: 5.2751e-05 - val_accuracy: 0.9479 - val_loss: 0.2879
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 65s 372ms/step - accuracy: 1.0000 - loss: 4.4911e-05 - val_accuracy: 0.9479 - val_loss: 0.2969
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 68s 388ms/step - accuracy: 1.0000 - loss: 4.0314e-05 - val_accuracy: 0.9479 - val_loss: 0.2914
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 69s 392ms/step - accuracy: 1.0000 - loss: 3.6599e-05 - val_accuracy: 0.9479 - val_loss: 0.2963
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 70s 402ms/step - accuracy: 1.0000 - loss: 3.4439e-05 - val_accuracy: 0.9479 - val_loss: 0.3041
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 71s 408ms/step - accuracy: 1.0000 - loss: 3.4895e-05 - val_accuracy: 0.9479 - val_loss: 0.2981
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 69s 394ms/step - accuracy: 1.0000 - loss: 2.9493e-05 - val_accuracy: 0.9464 - val_loss: 0.2989
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 69s 392ms/step - accuracy: 1.0000 - loss: 2.7964e-05 - val_accuracy: 0.9479 - val_loss: 0.3027

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 94.79%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'MobileNetV1_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 368ms/step - accuracy: 0.9514 - loss: 0.2208
# Test Accuracy: 93.57%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 377ms/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       0.99      0.99      0.99       100
#              Chickenpox       0.94      0.90      0.92       100
#                  Cowpox       0.97      0.97      0.97       100
#                    HFMD       0.95      0.92      0.93       100
#                 Healthy       0.95      0.95      0.95       100
#                 Measles       0.91      0.96      0.94       100
#               Monkeypox       0.84      0.86      0.85       100
#
#                accuracy                           0.94       700
#               macro avg       0.94      0.94      0.94       700
#            weighted avg       0.94      0.94      0.94       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

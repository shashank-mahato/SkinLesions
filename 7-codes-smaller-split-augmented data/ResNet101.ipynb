# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.ResNet101(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 457s 3s/step - accuracy: 0.2248 - loss: 1.9639 - val_accuracy: 0.2485 - val_loss: 1.7675
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 442s 3s/step - accuracy: 0.3163 - loss: 1.7306 - val_accuracy: 0.3006 - val_loss: 1.7452
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 454s 3s/step - accuracy: 0.3849 - loss: 1.6394 - val_accuracy: 0.3958 - val_loss: 1.6485
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 484s 3s/step - accuracy: 0.3881 - loss: 1.6004 - val_accuracy: 0.3348 - val_loss: 1.6823
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 450s 3s/step - accuracy: 0.3878 - loss: 1.5706 - val_accuracy: 0.4062 - val_loss: 1.5636
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 434s 2s/step - accuracy: 0.4289 - loss: 1.4864 - val_accuracy: 0.4107 - val_loss: 1.5257
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 415s 2s/step - accuracy: 0.4538 - loss: 1.4292 - val_accuracy: 0.4077 - val_loss: 1.4927
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 473s 3s/step - accuracy: 0.4351 - loss: 1.4390 - val_accuracy: 0.4152 - val_loss: 1.4973
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 453s 3s/step - accuracy: 0.4736 - loss: 1.3889 - val_accuracy: 0.4345 - val_loss: 1.4550
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 450s 3s/step - accuracy: 0.4832 - loss: 1.3598 - val_accuracy: 0.4420 - val_loss: 1.4254
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 448s 3s/step - accuracy: 0.5045 - loss: 1.3221 - val_accuracy: 0.4524 - val_loss: 1.4838
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 448s 3s/step - accuracy: 0.4940 - loss: 1.3263 - val_accuracy: 0.4717 - val_loss: 1.3539
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 447s 3s/step - accuracy: 0.5146 - loss: 1.2867 - val_accuracy: 0.4717 - val_loss: 1.3524
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 446s 3s/step - accuracy: 0.5305 - loss: 1.2491 - val_accuracy: 0.4211 - val_loss: 1.4953
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 447s 3s/step - accuracy: 0.5095 - loss: 1.2663 - val_accuracy: 0.4866 - val_loss: 1.3506
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 450s 3s/step - accuracy: 0.5348 - loss: 1.2212 - val_accuracy: 0.5060 - val_loss: 1.3597
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 451s 3s/step - accuracy: 0.5291 - loss: 1.2281 - val_accuracy: 0.4821 - val_loss: 1.3461
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 450s 3s/step - accuracy: 0.5481 - loss: 1.1830 - val_accuracy: 0.5015 - val_loss: 1.2940
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 446s 3s/step - accuracy: 0.5592 - loss: 1.1573 - val_accuracy: 0.5104 - val_loss: 1.3163
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 431s 2s/step - accuracy: 0.5561 - loss: 1.1653 - val_accuracy: 0.4762 - val_loss: 1.3714
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 444s 3s/step - accuracy: 0.5500 - loss: 1.1781 - val_accuracy: 0.5119 - val_loss: 1.3552
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 439s 3s/step - accuracy: 0.5544 - loss: 1.1553 - val_accuracy: 0.5045 - val_loss: 1.3850
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 437s 2s/step - accuracy: 0.5701 - loss: 1.1405 - val_accuracy: 0.5074 - val_loss: 1.3278
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 438s 3s/step - accuracy: 0.5866 - loss: 1.0836 - val_accuracy: 0.4955 - val_loss: 1.3174
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 441s 3s/step - accuracy: 0.5843 - loss: 1.0921 - val_accuracy: 0.5149 - val_loss: 1.2927
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 440s 3s/step - accuracy: 0.5894 - loss: 1.0810 - val_accuracy: 0.5179 - val_loss: 1.2693
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 436s 2s/step - accuracy: 0.6163 - loss: 1.0416 - val_accuracy: 0.5134 - val_loss: 1.2901
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 438s 3s/step - accuracy: 0.6010 - loss: 1.0623 - val_accuracy: 0.4866 - val_loss: 1.4150
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 406s 2s/step - accuracy: 0.6029 - loss: 1.0529 - val_accuracy: 0.5193 - val_loss: 1.3137
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 403s 2s/step - accuracy: 0.6130 - loss: 1.0384 - val_accuracy: 0.5074 - val_loss: 1.3644
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 403s 2s/step - accuracy: 0.6211 - loss: 0.9983 - val_accuracy: 0.4985 - val_loss: 1.3201
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 404s 2s/step - accuracy: 0.6046 - loss: 1.0289 - val_accuracy: 0.5432 - val_loss: 1.2831
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 638s 4s/step - accuracy: 0.6136 - loss: 1.0149 - val_accuracy: 0.5193 - val_loss: 1.3544
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 772s 4s/step - accuracy: 0.6065 - loss: 1.0290 - val_accuracy: 0.5357 - val_loss: 1.3074
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 374s 2s/step - accuracy: 0.6109 - loss: 1.0074 - val_accuracy: 0.5372 - val_loss: 1.2812
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 366s 2s/step - accuracy: 0.6236 - loss: 0.9922 - val_accuracy: 0.5372 - val_loss: 1.2891
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 365s 2s/step - accuracy: 0.6300 - loss: 0.9759 - val_accuracy: 0.5536 - val_loss: 1.3265
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 365s 2s/step - accuracy: 0.6254 - loss: 0.9831 - val_accuracy: 0.5565 - val_loss: 1.2819
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 366s 2s/step - accuracy: 0.6409 - loss: 0.9423 - val_accuracy: 0.5193 - val_loss: 1.3891
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 364s 2s/step - accuracy: 0.6336 - loss: 0.9741 - val_accuracy: 0.5640 - val_loss: 1.2996
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 364s 2s/step - accuracy: 0.6471 - loss: 0.9441 - val_accuracy: 0.5268 - val_loss: 1.3874
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 365s 2s/step - accuracy: 0.6287 - loss: 0.9536 - val_accuracy: 0.5491 - val_loss: 1.3294
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 365s 2s/step - accuracy: 0.6525 - loss: 0.9239 - val_accuracy: 0.5446 - val_loss: 1.3022
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 365s 2s/step - accuracy: 0.6514 - loss: 0.9203 - val_accuracy: 0.5149 - val_loss: 1.3748
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 364s 2s/step - accuracy: 0.6431 - loss: 0.9267 - val_accuracy: 0.5923 - val_loss: 1.2189
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 367s 2s/step - accuracy: 0.6590 - loss: 0.9080 - val_accuracy: 0.5357 - val_loss: 1.3228
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 364s 2s/step - accuracy: 0.6651 - loss: 0.8932 - val_accuracy: 0.5283 - val_loss: 1.3364
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 364s 2s/step - accuracy: 0.6609 - loss: 0.9339 - val_accuracy: 0.5104 - val_loss: 1.4369
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 363s 2s/step - accuracy: 0.6798 - loss: 0.8804 - val_accuracy: 0.4926 - val_loss: 1.4771
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 363s 2s/step - accuracy: 0.6488 - loss: 0.9215 - val_accuracy: 0.5595 - val_loss: 1.2805

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 55.95%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'ResNet101_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.6712 - loss: 1.0757
# Test Accuracy: 55.57%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       0.82      0.78      0.80       100
#              Chickenpox       0.43      0.72      0.54       100
#                  Cowpox       0.66      0.49      0.56       100
#                    HFMD       0.46      0.73      0.57       100
#                 Healthy       0.70      0.46      0.55       100
#                 Measles       0.62      0.35      0.45       100
#               Monkeypox       0.43      0.36      0.39       100
#
#                accuracy                           0.56       700
#               macro avg       0.59      0.56      0.55       700
#            weighted avg       0.59      0.56      0.55       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.DenseNet201(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 24s 0us/step

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 335s 2s/step - accuracy: 0.6996 - loss: 0.9109 - val_accuracy: 0.9092 - val_loss: 0.2599
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 323s 2s/step - accuracy: 0.9202 - loss: 0.2302 - val_accuracy: 0.9211 - val_loss: 0.2067
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 430s 2s/step - accuracy: 0.9494 - loss: 0.1406 - val_accuracy: 0.9241 - val_loss: 0.2258
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 460s 3s/step - accuracy: 0.9682 - loss: 0.0869 - val_accuracy: 0.9122 - val_loss: 0.2524
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 460s 3s/step - accuracy: 0.9835 - loss: 0.0591 - val_accuracy: 0.9241 - val_loss: 0.2269
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 451s 3s/step - accuracy: 0.9836 - loss: 0.0555 - val_accuracy: 0.9435 - val_loss: 0.1696
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 463s 3s/step - accuracy: 0.9950 - loss: 0.0218 - val_accuracy: 0.9420 - val_loss: 0.1754
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 457s 3s/step - accuracy: 0.9969 - loss: 0.0172 - val_accuracy: 0.9360 - val_loss: 0.1750
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 419s 2s/step - accuracy: 0.9975 - loss: 0.0131 - val_accuracy: 0.9390 - val_loss: 0.1908
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 416s 2s/step - accuracy: 0.9979 - loss: 0.0087 - val_accuracy: 0.9420 - val_loss: 0.1932
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 509s 3s/step - accuracy: 0.9997 - loss: 0.0044 - val_accuracy: 0.9405 - val_loss: 0.1859
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 491s 3s/step - accuracy: 0.9952 - loss: 0.0150 - val_accuracy: 0.9286 - val_loss: 0.2445
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 439s 3s/step - accuracy: 0.9622 - loss: 0.1245 - val_accuracy: 0.9226 - val_loss: 0.2464
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 444s 3s/step - accuracy: 0.9763 - loss: 0.0696 - val_accuracy: 0.9405 - val_loss: 0.2101
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 447s 3s/step - accuracy: 0.9973 - loss: 0.0119 - val_accuracy: 0.9449 - val_loss: 0.1873
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 451s 3s/step - accuracy: 0.9998 - loss: 0.0027 - val_accuracy: 0.9464 - val_loss: 0.1828
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 450s 3s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9479 - val_loss: 0.1838
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 474s 3s/step - accuracy: 1.0000 - loss: 8.7800e-04 - val_accuracy: 0.9449 - val_loss: 0.1935
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 459s 3s/step - accuracy: 1.0000 - loss: 7.7625e-04 - val_accuracy: 0.9479 - val_loss: 0.1852
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 453s 3s/step - accuracy: 1.0000 - loss: 5.9606e-04 - val_accuracy: 0.9464 - val_loss: 0.1936
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 474s 3s/step - accuracy: 1.0000 - loss: 4.0016e-04 - val_accuracy: 0.9479 - val_loss: 0.2021
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 476s 3s/step - accuracy: 1.0000 - loss: 3.8006e-04 - val_accuracy: 0.9449 - val_loss: 0.2006
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 460s 3s/step - accuracy: 1.0000 - loss: 3.1292e-04 - val_accuracy: 0.9464 - val_loss: 0.2000
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 457s 3s/step - accuracy: 1.0000 - loss: 3.0642e-04 - val_accuracy: 0.9449 - val_loss: 0.1951
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 452s 3s/step - accuracy: 1.0000 - loss: 2.5839e-04 - val_accuracy: 0.9449 - val_loss: 0.2114
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 457s 3s/step - accuracy: 1.0000 - loss: 2.3954e-04 - val_accuracy: 0.9479 - val_loss: 0.2094
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 455s 3s/step - accuracy: 1.0000 - loss: 2.1245e-04 - val_accuracy: 0.9464 - val_loss: 0.2050
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 461s 3s/step - accuracy: 1.0000 - loss: 1.9776e-04 - val_accuracy: 0.9464 - val_loss: 0.2094
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 474s 3s/step - accuracy: 1.0000 - loss: 1.9632e-04 - val_accuracy: 0.9464 - val_loss: 0.2097
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 479s 3s/step - accuracy: 1.0000 - loss: 1.5386e-04 - val_accuracy: 0.9464 - val_loss: 0.2049
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 466s 3s/step - accuracy: 1.0000 - loss: 1.5938e-04 - val_accuracy: 0.9479 - val_loss: 0.2096
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 495s 3s/step - accuracy: 1.0000 - loss: 1.3900e-04 - val_accuracy: 0.9479 - val_loss: 0.2096
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 516s 3s/step - accuracy: 1.0000 - loss: 1.1384e-04 - val_accuracy: 0.9449 - val_loss: 0.2160
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 531s 3s/step - accuracy: 1.0000 - loss: 1.1117e-04 - val_accuracy: 0.9479 - val_loss: 0.2100
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 491s 3s/step - accuracy: 1.0000 - loss: 9.8577e-05 - val_accuracy: 0.9464 - val_loss: 0.2109
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 492s 3s/step - accuracy: 1.0000 - loss: 9.1217e-05 - val_accuracy: 0.9464 - val_loss: 0.2174
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 496s 3s/step - accuracy: 1.0000 - loss: 8.9722e-05 - val_accuracy: 0.9479 - val_loss: 0.2125
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 493s 3s/step - accuracy: 1.0000 - loss: 8.0515e-05 - val_accuracy: 0.9479 - val_loss: 0.2162
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 498s 3s/step - accuracy: 1.0000 - loss: 6.1774e-05 - val_accuracy: 0.9494 - val_loss: 0.2170
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 509s 3s/step - accuracy: 1.0000 - loss: 6.1591e-05 - val_accuracy: 0.9479 - val_loss: 0.2260
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 503s 3s/step - accuracy: 1.0000 - loss: 5.6021e-05 - val_accuracy: 0.9494 - val_loss: 0.2192
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 501s 3s/step - accuracy: 1.0000 - loss: 5.6157e-05 - val_accuracy: 0.9479 - val_loss: 0.2227
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 502s 3s/step - accuracy: 1.0000 - loss: 5.1124e-05 - val_accuracy: 0.9449 - val_loss: 0.2244
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 505s 3s/step - accuracy: 1.0000 - loss: 4.5713e-05 - val_accuracy: 0.9479 - val_loss: 0.2232
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 524s 3s/step - accuracy: 1.0000 - loss: 4.2234e-05 - val_accuracy: 0.9464 - val_loss: 0.2229
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 545s 3s/step - accuracy: 1.0000 - loss: 3.8862e-05 - val_accuracy: 0.9464 - val_loss: 0.2289
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 431s 2s/step - accuracy: 1.0000 - loss: 3.5306e-05 - val_accuracy: 0.9464 - val_loss: 0.2248
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 374s 2s/step - accuracy: 1.0000 - loss: 3.1137e-05 - val_accuracy: 0.9479 - val_loss: 0.2328
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 378s 2s/step - accuracy: 1.0000 - loss: 2.8830e-05 - val_accuracy: 0.9449 - val_loss: 0.2322
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 346s 2s/step - accuracy: 1.0000 - loss: 2.5330e-05 - val_accuracy: 0.9479 - val_loss: 0.2327

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 94.79%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'DenseNet201_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9539 - loss: 0.2091
# Test Accuracy: 94.14%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       0.99      0.98      0.98       100
#              Chickenpox       0.87      0.94      0.90       100
#                  Cowpox       0.94      0.97      0.96       100
#                    HFMD       0.98      0.87      0.92       100
#                 Healthy       0.95      0.99      0.97       100
#                 Measles       0.96      0.96      0.96       100
#               Monkeypox       0.91      0.88      0.89       100
#
#                accuracy                           0.94       700
#               macro avg       0.94      0.94      0.94       700
#            weighted avg       0.94      0.94      0.94       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

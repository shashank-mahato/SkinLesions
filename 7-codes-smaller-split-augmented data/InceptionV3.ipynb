# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.InceptionV3(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 208s 1s/step - accuracy: 0.5638 - loss: 1.7390 - val_accuracy: 0.7932 - val_loss: 0.5942
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.8501 - loss: 0.4483 - val_accuracy: 0.8289 - val_loss: 0.4638
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47742s 274s/step - accuracy: 0.8981 - loss: 0.3040 - val_accuracy: 0.8750 - val_loss: 0.3455
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 144s 821ms/step - accuracy: 0.9302 - loss: 0.2065 - val_accuracy: 0.8810 - val_loss: 0.3341
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 157s 896ms/step - accuracy: 0.9469 - loss: 0.1630 - val_accuracy: 0.8810 - val_loss: 0.3185
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 158s 905ms/step - accuracy: 0.9663 - loss: 0.1137 - val_accuracy: 0.8780 - val_loss: 0.3402
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 152s 867ms/step - accuracy: 0.9648 - loss: 0.1072 - val_accuracy: 0.8929 - val_loss: 0.3134
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 165s 944ms/step - accuracy: 0.9854 - loss: 0.0669 - val_accuracy: 0.8661 - val_loss: 0.3774
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 164s 939ms/step - accuracy: 0.9823 - loss: 0.0598 - val_accuracy: 0.9062 - val_loss: 0.3213
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.9957 - loss: 0.0265 - val_accuracy: 0.8943 - val_loss: 0.3019
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.9917 - loss: 0.0315 - val_accuracy: 0.8839 - val_loss: 0.3590
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.9903 - loss: 0.0352 - val_accuracy: 0.8914 - val_loss: 0.3899
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 197s 1s/step - accuracy: 0.9912 - loss: 0.0302 - val_accuracy: 0.8973 - val_loss: 0.3212
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.9987 - loss: 0.0130 - val_accuracy: 0.9092 - val_loss: 0.2997
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9167 - val_loss: 0.2952
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 199s 1s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9152 - val_loss: 0.2942
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9137 - val_loss: 0.3010
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 199s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9137 - val_loss: 0.3057
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 1.0000 - loss: 9.5967e-04 - val_accuracy: 0.9137 - val_loss: 0.3149
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 149s 849ms/step - accuracy: 1.0000 - loss: 8.4138e-04 - val_accuracy: 0.9107 - val_loss: 0.3142
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 145s 827ms/step - accuracy: 1.0000 - loss: 6.8977e-04 - val_accuracy: 0.9048 - val_loss: 0.3210
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 197s 1s/step - accuracy: 1.0000 - loss: 6.3416e-04 - val_accuracy: 0.9137 - val_loss: 0.3164
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 221s 1s/step - accuracy: 1.0000 - loss: 6.2158e-04 - val_accuracy: 0.9137 - val_loss: 0.3190
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 1.0000 - loss: 5.0616e-04 - val_accuracy: 0.9152 - val_loss: 0.3182
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 1.0000 - loss: 4.4780e-04 - val_accuracy: 0.9092 - val_loss: 0.3219
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 160s 912ms/step - accuracy: 1.0000 - loss: 4.3321e-04 - val_accuracy: 0.9137 - val_loss: 0.3243
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 154s 882ms/step - accuracy: 1.0000 - loss: 3.8229e-04 - val_accuracy: 0.9137 - val_loss: 0.3270
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 153s 875ms/step - accuracy: 1.0000 - loss: 3.3476e-04 - val_accuracy: 0.9122 - val_loss: 0.3296
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 155s 887ms/step - accuracy: 1.0000 - loss: 3.3867e-04 - val_accuracy: 0.9137 - val_loss: 0.3328
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 156s 892ms/step - accuracy: 1.0000 - loss: 2.9850e-04 - val_accuracy: 0.9152 - val_loss: 0.3296
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 155s 885ms/step - accuracy: 1.0000 - loss: 2.6294e-04 - val_accuracy: 0.9122 - val_loss: 0.3346
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 170s 969ms/step - accuracy: 1.0000 - loss: 2.4978e-04 - val_accuracy: 0.9107 - val_loss: 0.3367
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 166s 946ms/step - accuracy: 1.0000 - loss: 2.0568e-04 - val_accuracy: 0.9122 - val_loss: 0.3397
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 174s 995ms/step - accuracy: 1.0000 - loss: 2.0516e-04 - val_accuracy: 0.9122 - val_loss: 0.3405
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 1.0000 - loss: 1.7586e-04 - val_accuracy: 0.9092 - val_loss: 0.3448
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 244s 1s/step - accuracy: 1.0000 - loss: 1.6061e-04 - val_accuracy: 0.9107 - val_loss: 0.3474
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 1.0000 - loss: 1.4715e-04 - val_accuracy: 0.9092 - val_loss: 0.3492
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 156s 892ms/step - accuracy: 1.0000 - loss: 1.3586e-04 - val_accuracy: 0.9122 - val_loss: 0.3509
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 152s 869ms/step - accuracy: 1.0000 - loss: 1.3153e-04 - val_accuracy: 0.9107 - val_loss: 0.3504
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 148s 847ms/step - accuracy: 1.0000 - loss: 1.1859e-04 - val_accuracy: 0.9107 - val_loss: 0.3535
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 148s 845ms/step - accuracy: 1.0000 - loss: 1.0743e-04 - val_accuracy: 0.9107 - val_loss: 0.3527
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 153s 873ms/step - accuracy: 1.0000 - loss: 9.3080e-05 - val_accuracy: 0.9107 - val_loss: 0.3587
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 156s 894ms/step - accuracy: 1.0000 - loss: 8.6350e-05 - val_accuracy: 0.9107 - val_loss: 0.3595
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 174s 997ms/step - accuracy: 1.0000 - loss: 7.5910e-05 - val_accuracy: 0.9107 - val_loss: 0.3633
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 1.0000 - loss: 7.0845e-05 - val_accuracy: 0.9092 - val_loss: 0.3614
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 160s 914ms/step - accuracy: 1.0000 - loss: 6.5341e-05 - val_accuracy: 0.9122 - val_loss: 0.3663
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 160s 914ms/step - accuracy: 1.0000 - loss: 6.1987e-05 - val_accuracy: 0.9122 - val_loss: 0.3672
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 160s 913ms/step - accuracy: 1.0000 - loss: 5.5469e-05 - val_accuracy: 0.9137 - val_loss: 0.3711
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 160s 913ms/step - accuracy: 1.0000 - loss: 5.0097e-05 - val_accuracy: 0.9137 - val_loss: 0.3733
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 161s 920ms/step - accuracy: 1.0000 - loss: 4.4254e-05 - val_accuracy: 0.9137 - val_loss: 0.3707

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 91.37%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'InceptionV3_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 18s 826ms/step - accuracy: 0.9149 - loss: 0.4433
# Test Accuracy: 89.43%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 22s 911ms/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       0.97      0.97      0.97       100
#              Chickenpox       0.87      0.87      0.87       100
#                  Cowpox       0.92      0.89      0.90       100
#                    HFMD       0.86      0.88      0.87       100
#                 Healthy       0.92      0.90      0.91       100
#                 Measles       0.89      0.95      0.92       100
#               Monkeypox       0.83      0.80      0.82       100
#
#                accuracy                           0.89       700
#               macro avg       0.89      0.89      0.89       700
#            weighted avg       0.89      0.89      0.89       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

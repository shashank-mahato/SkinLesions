# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.InceptionResNetV2(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.
# WARNING:tensorflow:From c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\tensorflow\core.py:216: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 ━━━━━━━━━━━━━━━━━━━━ 59s 0us/step

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 464s 3s/step - accuracy: 0.6031 - loss: 1.3519 - val_accuracy: 0.8185 - val_loss: 0.5085
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 376s 2s/step - accuracy: 0.8382 - loss: 0.4508 - val_accuracy: 0.8810 - val_loss: 0.3505
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.8993 - loss: 0.2842 - val_accuracy: 0.8839 - val_loss: 0.3091
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 350s 2s/step - accuracy: 0.8957 - loss: 0.2835 - val_accuracy: 0.8824 - val_loss: 0.3379
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 348s 2s/step - accuracy: 0.9344 - loss: 0.1825 - val_accuracy: 0.8824 - val_loss: 0.3035
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 385s 2s/step - accuracy: 0.9504 - loss: 0.1498 - val_accuracy: 0.8943 - val_loss: 0.2924
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 385s 2s/step - accuracy: 0.9522 - loss: 0.1401 - val_accuracy: 0.8973 - val_loss: 0.2735
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 391s 2s/step - accuracy: 0.9636 - loss: 0.0993 - val_accuracy: 0.9107 - val_loss: 0.2594
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 402s 2s/step - accuracy: 0.9713 - loss: 0.0785 - val_accuracy: 0.9033 - val_loss: 0.3222
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 422s 2s/step - accuracy: 0.9789 - loss: 0.0666 - val_accuracy: 0.9048 - val_loss: 0.3123
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 359s 2s/step - accuracy: 0.9755 - loss: 0.0657 - val_accuracy: 0.9107 - val_loss: 0.3046
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 337s 2s/step - accuracy: 0.9857 - loss: 0.0485 - val_accuracy: 0.9286 - val_loss: 0.2465
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 336s 2s/step - accuracy: 0.9829 - loss: 0.0547 - val_accuracy: 0.9077 - val_loss: 0.3076
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 347s 2s/step - accuracy: 0.9688 - loss: 0.1004 - val_accuracy: 0.9077 - val_loss: 0.3090
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 342s 2s/step - accuracy: 0.9866 - loss: 0.0420 - val_accuracy: 0.9345 - val_loss: 0.2159
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 335s 2s/step - accuracy: 0.9946 - loss: 0.0212 - val_accuracy: 0.9360 - val_loss: 0.2212
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 331s 2s/step - accuracy: 0.9975 - loss: 0.0108 - val_accuracy: 0.9360 - val_loss: 0.2094
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 355s 2s/step - accuracy: 0.9997 - loss: 0.0042 - val_accuracy: 0.9435 - val_loss: 0.2139
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 490s 3s/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9449 - val_loss: 0.2114
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 410s 2s/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9405 - val_loss: 0.2145
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 401s 2s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9449 - val_loss: 0.2235
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 370s 2s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9405 - val_loss: 0.2200
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9449 - val_loss: 0.2232
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 377s 2s/step - accuracy: 1.0000 - loss: 8.3761e-04 - val_accuracy: 0.9420 - val_loss: 0.2329
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 399s 2s/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 0.9420 - val_loss: 0.2246
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 347s 2s/step - accuracy: 1.0000 - loss: 7.6662e-04 - val_accuracy: 0.9375 - val_loss: 0.2329
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 330s 2s/step - accuracy: 0.9890 - loss: 0.0493 - val_accuracy: 0.8676 - val_loss: 0.4710
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 378s 2s/step - accuracy: 0.9196 - loss: 0.2531 - val_accuracy: 0.9167 - val_loss: 0.2886
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 389s 2s/step - accuracy: 0.9776 - loss: 0.0649 - val_accuracy: 0.9271 - val_loss: 0.2409
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 381s 2s/step - accuracy: 0.9915 - loss: 0.0266 - val_accuracy: 0.9449 - val_loss: 0.2063
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 374s 2s/step - accuracy: 0.9987 - loss: 0.0098 - val_accuracy: 0.9301 - val_loss: 0.2597
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 394s 2s/step - accuracy: 0.9973 - loss: 0.0136 - val_accuracy: 0.9390 - val_loss: 0.2372
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 368s 2s/step - accuracy: 0.9980 - loss: 0.0096 - val_accuracy: 0.9330 - val_loss: 0.2399
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 357s 2s/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9405 - val_loss: 0.2180
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 357s 2s/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9435 - val_loss: 0.2220
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 338s 2s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9405 - val_loss: 0.2179
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 336s 2s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9449 - val_loss: 0.2154
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4869s 28s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9405 - val_loss: 0.2255
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 346s 2s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9390 - val_loss: 0.2265
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 427s 2s/step - accuracy: 1.0000 - loss: 7.7618e-04 - val_accuracy: 0.9405 - val_loss: 0.2187
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 442s 3s/step - accuracy: 1.0000 - loss: 9.1950e-04 - val_accuracy: 0.9375 - val_loss: 0.2269
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 383s 2s/step - accuracy: 1.0000 - loss: 7.0660e-04 - val_accuracy: 0.9390 - val_loss: 0.2354
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 393s 2s/step - accuracy: 1.0000 - loss: 6.6407e-04 - val_accuracy: 0.9435 - val_loss: 0.2347
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 372s 2s/step - accuracy: 1.0000 - loss: 5.5394e-04 - val_accuracy: 0.9375 - val_loss: 0.2406
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 363s 2s/step - accuracy: 1.0000 - loss: 5.5330e-04 - val_accuracy: 0.9405 - val_loss: 0.2392
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 353s 2s/step - accuracy: 1.0000 - loss: 4.5603e-04 - val_accuracy: 0.9435 - val_loss: 0.2414
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 368s 2s/step - accuracy: 1.0000 - loss: 4.2638e-04 - val_accuracy: 0.9449 - val_loss: 0.2479
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 364s 2s/step - accuracy: 1.0000 - loss: 4.0413e-04 - val_accuracy: 0.9420 - val_loss: 0.2400
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 370s 2s/step - accuracy: 1.0000 - loss: 3.5001e-04 - val_accuracy: 0.9420 - val_loss: 0.2475
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 366s 2s/step - accuracy: 1.0000 - loss: 3.0243e-04 - val_accuracy: 0.9390 - val_loss: 0.2506

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 93.90%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'InceptionResNetV2_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9485 - loss: 0.2124
# Test Accuracy: 93.14%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       1.00      0.99      0.99       100
#              Chickenpox       0.88      0.89      0.89       100
#                  Cowpox       0.92      0.95      0.94       100
#                    HFMD       0.92      0.94      0.93       100
#                 Healthy       0.93      0.95      0.94       100
#                 Measles       0.97      0.93      0.95       100
#               Monkeypox       0.90      0.87      0.88       100
#
#                accuracy                           0.93       700
#               macro avg       0.93      0.93      0.93       700
#            weighted avg       0.93      0.93      0.93       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

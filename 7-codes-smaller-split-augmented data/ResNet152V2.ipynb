# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.ResNet152V2(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 707s 4s/step - accuracy: 0.7159 - loss: 0.8959 - val_accuracy: 0.8735 - val_loss: 0.3692
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 701s 4s/step - accuracy: 0.9411 - loss: 0.1783 - val_accuracy: 0.9137 - val_loss: 0.2270
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 744s 4s/step - accuracy: 0.9766 - loss: 0.0748 - val_accuracy: 0.9182 - val_loss: 0.2060
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1928s 11s/step - accuracy: 0.9916 - loss: 0.0348 - val_accuracy: 0.9271 - val_loss: 0.1809
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 577s 3s/step - accuracy: 0.9940 - loss: 0.0230 - val_accuracy: 0.9390 - val_loss: 0.1772
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 591s 3s/step - accuracy: 0.9912 - loss: 0.0328 - val_accuracy: 0.9062 - val_loss: 0.2691
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 578s 3s/step - accuracy: 0.9928 - loss: 0.0302 - val_accuracy: 0.9196 - val_loss: 0.2673
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 582s 3s/step - accuracy: 0.9877 - loss: 0.0369 - val_accuracy: 0.8705 - val_loss: 0.5849
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 594s 3s/step - accuracy: 0.9840 - loss: 0.0482 - val_accuracy: 0.9345 - val_loss: 0.2466
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 578s 3s/step - accuracy: 0.9893 - loss: 0.0356 - val_accuracy: 0.9241 - val_loss: 0.2649
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 580s 3s/step - accuracy: 0.9980 - loss: 0.0072 - val_accuracy: 0.9405 - val_loss: 0.2409
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 579s 3s/step - accuracy: 0.9995 - loss: 0.0034 - val_accuracy: 0.9345 - val_loss: 0.1971
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 578s 3s/step - accuracy: 1.0000 - loss: 4.9155e-04 - val_accuracy: 0.9390 - val_loss: 0.1993
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 575s 3s/step - accuracy: 1.0000 - loss: 3.1092e-04 - val_accuracy: 0.9390 - val_loss: 0.1982
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 574s 3s/step - accuracy: 1.0000 - loss: 2.4951e-04 - val_accuracy: 0.9390 - val_loss: 0.1989
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 579s 3s/step - accuracy: 1.0000 - loss: 2.0791e-04 - val_accuracy: 0.9390 - val_loss: 0.1989
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 573s 3s/step - accuracy: 1.0000 - loss: 1.8136e-04 - val_accuracy: 0.9420 - val_loss: 0.2019
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 566s 3s/step - accuracy: 1.0000 - loss: 1.6739e-04 - val_accuracy: 0.9420 - val_loss: 0.2016
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 558s 3s/step - accuracy: 1.0000 - loss: 1.3974e-04 - val_accuracy: 0.9435 - val_loss: 0.2031
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 556s 3s/step - accuracy: 1.0000 - loss: 1.2891e-04 - val_accuracy: 0.9435 - val_loss: 0.2030
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 560s 3s/step - accuracy: 1.0000 - loss: 1.0034e-04 - val_accuracy: 0.9435 - val_loss: 0.2043
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 560s 3s/step - accuracy: 1.0000 - loss: 9.4600e-05 - val_accuracy: 0.9435 - val_loss: 0.2060
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 559s 3s/step - accuracy: 1.0000 - loss: 8.8852e-05 - val_accuracy: 0.9435 - val_loss: 0.2066
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 562s 3s/step - accuracy: 1.0000 - loss: 7.9215e-05 - val_accuracy: 0.9435 - val_loss: 0.2075
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 556s 3s/step - accuracy: 1.0000 - loss: 6.9664e-05 - val_accuracy: 0.9435 - val_loss: 0.2080
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 557s 3s/step - accuracy: 1.0000 - loss: 6.2345e-05 - val_accuracy: 0.9435 - val_loss: 0.2098
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 557s 3s/step - accuracy: 1.0000 - loss: 5.5981e-05 - val_accuracy: 0.9435 - val_loss: 0.2098
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 559s 3s/step - accuracy: 1.0000 - loss: 5.5444e-05 - val_accuracy: 0.9449 - val_loss: 0.2105
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 556s 3s/step - accuracy: 1.0000 - loss: 5.2789e-05 - val_accuracy: 0.9435 - val_loss: 0.2109
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 556s 3s/step - accuracy: 1.0000 - loss: 4.4495e-05 - val_accuracy: 0.9449 - val_loss: 0.2150
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 557s 3s/step - accuracy: 1.0000 - loss: 4.1653e-05 - val_accuracy: 0.9435 - val_loss: 0.2135
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 554s 3s/step - accuracy: 1.0000 - loss: 4.0096e-05 - val_accuracy: 0.9435 - val_loss: 0.2151
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 556s 3s/step - accuracy: 1.0000 - loss: 3.3881e-05 - val_accuracy: 0.9435 - val_loss: 0.2162
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 557s 3s/step - accuracy: 1.0000 - loss: 3.1238e-05 - val_accuracy: 0.9435 - val_loss: 0.2159
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 560s 3s/step - accuracy: 1.0000 - loss: 2.9076e-05 - val_accuracy: 0.9435 - val_loss: 0.2165
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 557s 3s/step - accuracy: 1.0000 - loss: 2.5607e-05 - val_accuracy: 0.9449 - val_loss: 0.2189
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 558s 3s/step - accuracy: 1.0000 - loss: 2.3750e-05 - val_accuracy: 0.9420 - val_loss: 0.2182
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 559s 3s/step - accuracy: 1.0000 - loss: 2.1440e-05 - val_accuracy: 0.9435 - val_loss: 0.2207
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 561s 3s/step - accuracy: 1.0000 - loss: 2.1000e-05 - val_accuracy: 0.9420 - val_loss: 0.2210
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 558s 3s/step - accuracy: 1.0000 - loss: 1.7977e-05 - val_accuracy: 0.9420 - val_loss: 0.2224
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 557s 3s/step - accuracy: 1.0000 - loss: 1.7978e-05 - val_accuracy: 0.9420 - val_loss: 0.2227
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 558s 3s/step - accuracy: 1.0000 - loss: 1.6852e-05 - val_accuracy: 0.9420 - val_loss: 0.2230
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 557s 3s/step - accuracy: 1.0000 - loss: 1.4656e-05 - val_accuracy: 0.9420 - val_loss: 0.2249
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 573s 3s/step - accuracy: 1.0000 - loss: 1.4361e-05 - val_accuracy: 0.9420 - val_loss: 0.2255
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 553s 3s/step - accuracy: 1.0000 - loss: 1.1781e-05 - val_accuracy: 0.9435 - val_loss: 0.2298
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 564s 3s/step - accuracy: 1.0000 - loss: 1.1793e-05 - val_accuracy: 0.9435 - val_loss: 0.2305
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 555s 3s/step - accuracy: 1.0000 - loss: 9.8503e-06 - val_accuracy: 0.9420 - val_loss: 0.2293
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 559s 3s/step - accuracy: 1.0000 - loss: 9.6397e-06 - val_accuracy: 0.9435 - val_loss: 0.2311
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 556s 3s/step - accuracy: 1.0000 - loss: 7.6653e-06 - val_accuracy: 0.9435 - val_loss: 0.2326
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 567s 3s/step - accuracy: 1.0000 - loss: 7.2098e-06 - val_accuracy: 0.9420 - val_loss: 0.2330

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 94.20%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'ResNet152V2_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.9677 - loss: 0.1457
# Test Accuracy: 94.14%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       0.98      1.00      0.99       100
#              Chickenpox       0.89      0.96      0.92       100
#                  Cowpox       0.97      0.95      0.96       100
#                    HFMD       0.96      0.92      0.94       100
#                 Healthy       0.93      0.95      0.94       100
#                 Measles       0.94      0.98      0.96       100
#               Monkeypox       0.92      0.83      0.87       100
#
#                accuracy                           0.94       700
#               macro avg       0.94      0.94      0.94       700
#            weighted avg       0.94      0.94      0.94       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

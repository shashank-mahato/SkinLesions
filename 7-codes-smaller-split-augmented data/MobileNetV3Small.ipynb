# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.MobileNetV3Small(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='swish')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 43s 214ms/step - accuracy: 0.1643 - loss: 1.9827 - val_accuracy: 0.2009 - val_loss: 1.8973
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 205ms/step - accuracy: 0.2099 - loss: 1.8926 - val_accuracy: 0.1964 - val_loss: 1.8708
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 192ms/step - accuracy: 0.2209 - loss: 1.8782 - val_accuracy: 0.2827 - val_loss: 1.8506
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 39s 225ms/step - accuracy: 0.2565 - loss: 1.8419 - val_accuracy: 0.2887 - val_loss: 1.8156
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.2693 - loss: 1.8084 - val_accuracy: 0.2589 - val_loss: 1.8133
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 35s 200ms/step - accuracy: 0.2985 - loss: 1.7798 - val_accuracy: 0.3080 - val_loss: 1.7787
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 189ms/step - accuracy: 0.3059 - loss: 1.7687 - val_accuracy: 0.3006 - val_loss: 1.7585
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 35s 197ms/step - accuracy: 0.2863 - loss: 1.7692 - val_accuracy: 0.3289 - val_loss: 1.6998
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 194ms/step - accuracy: 0.3262 - loss: 1.7027 - val_accuracy: 0.3214 - val_loss: 1.7386
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 188ms/step - accuracy: 0.3265 - loss: 1.7141 - val_accuracy: 0.3482 - val_loss: 1.6507
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 35s 200ms/step - accuracy: 0.3216 - loss: 1.6996 - val_accuracy: 0.3289 - val_loss: 1.6887
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 191ms/step - accuracy: 0.3297 - loss: 1.7192 - val_accuracy: 0.3824 - val_loss: 1.6281
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 35s 202ms/step - accuracy: 0.3455 - loss: 1.6640 - val_accuracy: 0.3452 - val_loss: 1.6441
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 39s 222ms/step - accuracy: 0.3368 - loss: 1.6815 - val_accuracy: 0.3899 - val_loss: 1.6061
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 211ms/step - accuracy: 0.3608 - loss: 1.6402 - val_accuracy: 0.3259 - val_loss: 1.7810
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 40s 226ms/step - accuracy: 0.3360 - loss: 1.6774 - val_accuracy: 0.3497 - val_loss: 1.6990
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - accuracy: 0.3605 - loss: 1.6410 - val_accuracy: 0.3631 - val_loss: 1.6582
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - accuracy: 0.3642 - loss: 1.6253 - val_accuracy: 0.4003 - val_loss: 1.6002
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - accuracy: 0.3702 - loss: 1.6188 - val_accuracy: 0.4003 - val_loss: 1.6283
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - accuracy: 0.3827 - loss: 1.5996 - val_accuracy: 0.2946 - val_loss: 1.7167
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 207ms/step - accuracy: 0.3565 - loss: 1.6234 - val_accuracy: 0.4152 - val_loss: 1.5482
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 38s 218ms/step - accuracy: 0.3868 - loss: 1.5755 - val_accuracy: 0.3646 - val_loss: 1.6111
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - accuracy: 0.3752 - loss: 1.6037 - val_accuracy: 0.4211 - val_loss: 1.5814
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 40s 227ms/step - accuracy: 0.3662 - loss: 1.6204 - val_accuracy: 0.3586 - val_loss: 1.6297
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 39s 221ms/step - accuracy: 0.3808 - loss: 1.5739 - val_accuracy: 0.4167 - val_loss: 1.5392
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 211ms/step - accuracy: 0.3917 - loss: 1.5719 - val_accuracy: 0.3914 - val_loss: 1.5652
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 189ms/step - accuracy: 0.3788 - loss: 1.5862 - val_accuracy: 0.4152 - val_loss: 1.5115
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 188ms/step - accuracy: 0.4050 - loss: 1.5625 - val_accuracy: 0.3973 - val_loss: 1.5384
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 186ms/step - accuracy: 0.4091 - loss: 1.5397 - val_accuracy: 0.4256 - val_loss: 1.5184
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.3897 - loss: 1.5637 - val_accuracy: 0.4167 - val_loss: 1.5305
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 194ms/step - accuracy: 0.3998 - loss: 1.5472 - val_accuracy: 0.4211 - val_loss: 1.5128
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 196ms/step - accuracy: 0.3968 - loss: 1.5528 - val_accuracy: 0.4658 - val_loss: 1.4984
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 35s 199ms/step - accuracy: 0.3979 - loss: 1.5567 - val_accuracy: 0.3929 - val_loss: 1.5705
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 30s 172ms/step - accuracy: 0.4099 - loss: 1.5467 - val_accuracy: 0.4077 - val_loss: 1.5346
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 191ms/step - accuracy: 0.4011 - loss: 1.5398 - val_accuracy: 0.4330 - val_loss: 1.4866
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 31s 177ms/step - accuracy: 0.4191 - loss: 1.5196 - val_accuracy: 0.4464 - val_loss: 1.4701
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.4414 - loss: 1.4911 - val_accuracy: 0.4048 - val_loss: 1.5320
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 194ms/step - accuracy: 0.3966 - loss: 1.5631 - val_accuracy: 0.4286 - val_loss: 1.5150
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 194ms/step - accuracy: 0.4241 - loss: 1.5166 - val_accuracy: 0.4524 - val_loss: 1.4644
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 193ms/step - accuracy: 0.4271 - loss: 1.5079 - val_accuracy: 0.3869 - val_loss: 1.6004
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 195ms/step - accuracy: 0.4210 - loss: 1.5157 - val_accuracy: 0.4271 - val_loss: 1.5312
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 194ms/step - accuracy: 0.4365 - loss: 1.4834 - val_accuracy: 0.4405 - val_loss: 1.4518
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 195ms/step - accuracy: 0.4274 - loss: 1.4967 - val_accuracy: 0.4301 - val_loss: 1.4951
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.4259 - loss: 1.5207 - val_accuracy: 0.4658 - val_loss: 1.4521
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.4248 - loss: 1.4841 - val_accuracy: 0.4062 - val_loss: 1.4931
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 35s 199ms/step - accuracy: 0.4400 - loss: 1.4822 - val_accuracy: 0.4464 - val_loss: 1.4617
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 35s 202ms/step - accuracy: 0.4269 - loss: 1.4866 - val_accuracy: 0.4688 - val_loss: 1.4192
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 207ms/step - accuracy: 0.4451 - loss: 1.4665 - val_accuracy: 0.4658 - val_loss: 1.4473
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.4442 - loss: 1.4644 - val_accuracy: 0.4568 - val_loss: 1.4364
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 182ms/step - accuracy: 0.4342 - loss: 1.4704 - val_accuracy: 0.4256 - val_loss: 1.4824

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 42.56%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'MobileNetV3Small_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.4564 - loss: 1.5954
# Test Accuracy: 42.71%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       0.96      0.64      0.77       100
#              Chickenpox       0.67      0.04      0.08       100
#                  Cowpox       0.38      0.67      0.49       100
#                    HFMD       0.58      0.28      0.38       100
#                 Healthy       0.48      0.57      0.52       100
#                 Measles       0.30      0.63      0.40       100
#               Monkeypox       0.23      0.16      0.19       100
#
#                accuracy                           0.43       700
#               macro avg       0.51      0.43      0.40       700
#            weighted avg       0.51      0.43      0.40       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

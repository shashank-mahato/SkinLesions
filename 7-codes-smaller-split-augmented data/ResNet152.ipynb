# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.ResNet152(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# Epoch 1/50
# c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 598s 3s/step - accuracy: 0.2143 - loss: 1.9622 - val_accuracy: 0.3199 - val_loss: 1.8294
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 559s 3s/step - accuracy: 0.3070 - loss: 1.7308 - val_accuracy: 0.3021 - val_loss: 1.7159
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 581s 3s/step - accuracy: 0.3475 - loss: 1.6656 - val_accuracy: 0.3155 - val_loss: 1.7190
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 542s 3s/step - accuracy: 0.3646 - loss: 1.6288 - val_accuracy: 0.3318 - val_loss: 1.6567
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 547s 3s/step - accuracy: 0.3669 - loss: 1.5963 - val_accuracy: 0.3586 - val_loss: 1.6464
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 550s 3s/step - accuracy: 0.4001 - loss: 1.5577 - val_accuracy: 0.3586 - val_loss: 1.6364
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 574s 3s/step - accuracy: 0.4245 - loss: 1.5023 - val_accuracy: 0.4018 - val_loss: 1.5886
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 593s 3s/step - accuracy: 0.4100 - loss: 1.4960 - val_accuracy: 0.3958 - val_loss: 1.5939
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 682s 4s/step - accuracy: 0.4473 - loss: 1.4399 - val_accuracy: 0.3780 - val_loss: 1.6335
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 719s 4s/step - accuracy: 0.4410 - loss: 1.4316 - val_accuracy: 0.3810 - val_loss: 1.6154
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 724s 4s/step - accuracy: 0.4443 - loss: 1.4209 - val_accuracy: 0.4301 - val_loss: 1.5119
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 731s 4s/step - accuracy: 0.4779 - loss: 1.3696 - val_accuracy: 0.3988 - val_loss: 1.5421
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 766s 4s/step - accuracy: 0.4969 - loss: 1.3487 - val_accuracy: 0.4301 - val_loss: 1.5315
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 790s 5s/step - accuracy: 0.4885 - loss: 1.3427 - val_accuracy: 0.4375 - val_loss: 1.4894
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 795s 5s/step - accuracy: 0.4960 - loss: 1.3171 - val_accuracy: 0.3943 - val_loss: 1.6797
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 987s 6s/step - accuracy: 0.5054 - loss: 1.3231 - val_accuracy: 0.4077 - val_loss: 1.5580
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1096s 6s/step - accuracy: 0.5155 - loss: 1.2810 - val_accuracy: 0.4390 - val_loss: 1.4839
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 813s 5s/step - accuracy: 0.5224 - loss: 1.2339 - val_accuracy: 0.4271 - val_loss: 1.5337
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 802s 5s/step - accuracy: 0.5286 - loss: 1.2469 - val_accuracy: 0.4330 - val_loss: 1.5134
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 824s 5s/step - accuracy: 0.5347 - loss: 1.2271 - val_accuracy: 0.4568 - val_loss: 1.4516
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 721s 4s/step - accuracy: 0.5626 - loss: 1.1646 - val_accuracy: 0.4420 - val_loss: 1.4839
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 736s 4s/step - accuracy: 0.5613 - loss: 1.1681 - val_accuracy: 0.4836 - val_loss: 1.4187
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 721s 4s/step - accuracy: 0.5647 - loss: 1.1344 - val_accuracy: 0.4330 - val_loss: 1.5309
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 725s 4s/step - accuracy: 0.5601 - loss: 1.1441 - val_accuracy: 0.4509 - val_loss: 1.5055
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 728s 4s/step - accuracy: 0.5512 - loss: 1.1824 - val_accuracy: 0.4286 - val_loss: 1.5071
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 730s 4s/step - accuracy: 0.5768 - loss: 1.1212 - val_accuracy: 0.4717 - val_loss: 1.4309
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 739s 4s/step - accuracy: 0.5812 - loss: 1.1121 - val_accuracy: 0.4033 - val_loss: 1.6409
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 740s 4s/step - accuracy: 0.5788 - loss: 1.1213 - val_accuracy: 0.4762 - val_loss: 1.4900
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 760s 4s/step - accuracy: 0.5851 - loss: 1.0946 - val_accuracy: 0.4866 - val_loss: 1.4741
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 791s 5s/step - accuracy: 0.6063 - loss: 1.0706 - val_accuracy: 0.4821 - val_loss: 1.4457
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1117s 6s/step - accuracy: 0.6040 - loss: 1.0502 - val_accuracy: 0.4866 - val_loss: 1.4539
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1581s 9s/step - accuracy: 0.6150 - loss: 1.0194 - val_accuracy: 0.4107 - val_loss: 1.6361
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 793s 5s/step - accuracy: 0.5961 - loss: 1.0341 - val_accuracy: 0.4464 - val_loss: 1.6246
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 744s 4s/step - accuracy: 0.6074 - loss: 1.0289 - val_accuracy: 0.5208 - val_loss: 1.4392
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 738s 4s/step - accuracy: 0.6123 - loss: 1.0338 - val_accuracy: 0.4568 - val_loss: 1.5598
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 735s 4s/step - accuracy: 0.6225 - loss: 1.0019 - val_accuracy: 0.4628 - val_loss: 1.5659
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 986s 6s/step - accuracy: 0.6351 - loss: 0.9588 - val_accuracy: 0.4866 - val_loss: 1.4633
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1556s 9s/step - accuracy: 0.6178 - loss: 1.0065 - val_accuracy: 0.5074 - val_loss: 1.4537
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 776s 4s/step - accuracy: 0.6465 - loss: 0.9574 - val_accuracy: 0.5060 - val_loss: 1.4753
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 755s 4s/step - accuracy: 0.6455 - loss: 0.9455 - val_accuracy: 0.4955 - val_loss: 1.5450
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 743s 4s/step - accuracy: 0.6328 - loss: 0.9786 - val_accuracy: 0.4717 - val_loss: 1.5882
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 724s 4s/step - accuracy: 0.6454 - loss: 0.9477 - val_accuracy: 0.5506 - val_loss: 1.4824
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 720s 4s/step - accuracy: 0.6501 - loss: 0.9278 - val_accuracy: 0.4985 - val_loss: 1.5211
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 723s 4s/step - accuracy: 0.6365 - loss: 0.9399 - val_accuracy: 0.4717 - val_loss: 1.5635
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 716s 4s/step - accuracy: 0.6376 - loss: 0.9459 - val_accuracy: 0.5461 - val_loss: 1.4358
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 722s 4s/step - accuracy: 0.6542 - loss: 0.9279 - val_accuracy: 0.5089 - val_loss: 1.5280
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 717s 4s/step - accuracy: 0.6582 - loss: 0.9128 - val_accuracy: 0.4762 - val_loss: 1.6123
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 717s 4s/step - accuracy: 0.6711 - loss: 0.8993 - val_accuracy: 0.4792 - val_loss: 1.5618
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 720s 4s/step - accuracy: 0.6688 - loss: 0.8878 - val_accuracy: 0.5283 - val_loss: 1.5463
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 720s 4s/step - accuracy: 0.6765 - loss: 0.8597 - val_accuracy: 0.5461 - val_loss: 1.4661

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 54.61%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'ResNet152_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.6261 - loss: 1.2769
# Test Accuracy: 54.29%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       0.59      0.79      0.68       100
#              Chickenpox       0.51      0.46      0.48       100
#                  Cowpox       0.58      0.38      0.46       100
#                    HFMD       0.49      0.77      0.60       100
#                 Healthy       0.54      0.67      0.60       100
#                 Measles       0.61      0.55      0.58       100
#               Monkeypox       0.46      0.18      0.26       100
#
#                accuracy                           0.54       700
#               macro avg       0.54      0.54      0.52       700
#            weighted avg       0.54      0.54      0.52       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

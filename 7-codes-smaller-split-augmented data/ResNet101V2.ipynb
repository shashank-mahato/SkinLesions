# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.ResNet101V2(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# Epoch 1/50
# c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 337s 2s/step - accuracy: 0.7053 - loss: 0.9657 - val_accuracy: 0.8988 - val_loss: 0.2677
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 327s 2s/step - accuracy: 0.9429 - loss: 0.1749 - val_accuracy: 0.9241 - val_loss: 0.2122
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 332s 2s/step - accuracy: 0.9836 - loss: 0.0662 - val_accuracy: 0.9182 - val_loss: 0.2409
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 334s 2s/step - accuracy: 0.9893 - loss: 0.0406 - val_accuracy: 0.9301 - val_loss: 0.1910
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 0.9969 - loss: 0.0147 - val_accuracy: 0.9226 - val_loss: 0.2246
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 335s 2s/step - accuracy: 0.9911 - loss: 0.0284 - val_accuracy: 0.9375 - val_loss: 0.1773
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 0.9964 - loss: 0.0140 - val_accuracy: 0.9033 - val_loss: 0.3288
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 331s 2s/step - accuracy: 0.9967 - loss: 0.0143 - val_accuracy: 0.9405 - val_loss: 0.1592
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9435 - val_loss: 0.1568
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 332s 2s/step - accuracy: 1.0000 - loss: 5.6717e-04 - val_accuracy: 0.9464 - val_loss: 0.1549
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 331s 2s/step - accuracy: 1.0000 - loss: 4.9679e-04 - val_accuracy: 0.9435 - val_loss: 0.1591
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 331s 2s/step - accuracy: 1.0000 - loss: 3.6523e-04 - val_accuracy: 0.9420 - val_loss: 0.1604
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 330s 2s/step - accuracy: 1.0000 - loss: 3.1076e-04 - val_accuracy: 0.9405 - val_loss: 0.1611
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 331s 2s/step - accuracy: 1.0000 - loss: 2.6316e-04 - val_accuracy: 0.9464 - val_loss: 0.1631
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 332s 2s/step - accuracy: 1.0000 - loss: 2.3123e-04 - val_accuracy: 0.9435 - val_loss: 0.1653
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 330s 2s/step - accuracy: 1.0000 - loss: 1.9666e-04 - val_accuracy: 0.9420 - val_loss: 0.1667
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 1.0000 - loss: 1.7908e-04 - val_accuracy: 0.9420 - val_loss: 0.1686
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 332s 2s/step - accuracy: 1.0000 - loss: 1.6104e-04 - val_accuracy: 0.9435 - val_loss: 0.1685
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 330s 2s/step - accuracy: 1.0000 - loss: 1.4407e-04 - val_accuracy: 0.9405 - val_loss: 0.1677
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 332s 2s/step - accuracy: 1.0000 - loss: 1.2808e-04 - val_accuracy: 0.9435 - val_loss: 0.1695
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 332s 2s/step - accuracy: 1.0000 - loss: 1.1484e-04 - val_accuracy: 0.9420 - val_loss: 0.1702
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 332s 2s/step - accuracy: 1.0000 - loss: 1.0532e-04 - val_accuracy: 0.9479 - val_loss: 0.1713
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 1.0000 - loss: 9.5251e-05 - val_accuracy: 0.9449 - val_loss: 0.1719
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 331s 2s/step - accuracy: 1.0000 - loss: 8.8827e-05 - val_accuracy: 0.9449 - val_loss: 0.1731
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 1.0000 - loss: 7.4846e-05 - val_accuracy: 0.9420 - val_loss: 0.1743
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 337s 2s/step - accuracy: 1.0000 - loss: 7.0368e-05 - val_accuracy: 0.9464 - val_loss: 0.1755
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 1.0000 - loss: 6.6283e-05 - val_accuracy: 0.9464 - val_loss: 0.1770
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 334s 2s/step - accuracy: 1.0000 - loss: 5.7715e-05 - val_accuracy: 0.9479 - val_loss: 0.1786
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 332s 2s/step - accuracy: 1.0000 - loss: 4.9941e-05 - val_accuracy: 0.9464 - val_loss: 0.1769
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 332s 2s/step - accuracy: 1.0000 - loss: 4.5397e-05 - val_accuracy: 0.9464 - val_loss: 0.1792
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 1.0000 - loss: 4.0134e-05 - val_accuracy: 0.9449 - val_loss: 0.1794
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 331s 2s/step - accuracy: 1.0000 - loss: 3.6637e-05 - val_accuracy: 0.9449 - val_loss: 0.1838
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 331s 2s/step - accuracy: 1.0000 - loss: 3.6621e-05 - val_accuracy: 0.9464 - val_loss: 0.1843
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 1.0000 - loss: 2.9211e-05 - val_accuracy: 0.9494 - val_loss: 0.1826
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 332s 2s/step - accuracy: 1.0000 - loss: 2.7330e-05 - val_accuracy: 0.9464 - val_loss: 0.1827
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 1.0000 - loss: 2.6140e-05 - val_accuracy: 0.9449 - val_loss: 0.1853
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 1.0000 - loss: 2.3060e-05 - val_accuracy: 0.9464 - val_loss: 0.1853
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 334s 2s/step - accuracy: 1.0000 - loss: 2.1715e-05 - val_accuracy: 0.9464 - val_loss: 0.1892
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 1.0000 - loss: 1.9825e-05 - val_accuracy: 0.9479 - val_loss: 0.1884
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 1.0000 - loss: 1.6874e-05 - val_accuracy: 0.9479 - val_loss: 0.1880
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 1.0000 - loss: 1.5478e-05 - val_accuracy: 0.9479 - val_loss: 0.1885
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 334s 2s/step - accuracy: 1.0000 - loss: 1.5138e-05 - val_accuracy: 0.9479 - val_loss: 0.1913
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 332s 2s/step - accuracy: 1.0000 - loss: 1.3600e-05 - val_accuracy: 0.9449 - val_loss: 0.1921
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 332s 2s/step - accuracy: 1.0000 - loss: 1.3245e-05 - val_accuracy: 0.9464 - val_loss: 0.1933
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 335s 2s/step - accuracy: 1.0000 - loss: 1.1230e-05 - val_accuracy: 0.9464 - val_loss: 0.1928
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 334s 2s/step - accuracy: 1.0000 - loss: 1.0545e-05 - val_accuracy: 0.9464 - val_loss: 0.1943
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - accuracy: 1.0000 - loss: 9.2961e-06 - val_accuracy: 0.9479 - val_loss: 0.1967
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 334s 2s/step - accuracy: 1.0000 - loss: 8.5668e-06 - val_accuracy: 0.9464 - val_loss: 0.1951
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 335s 2s/step - accuracy: 1.0000 - loss: 7.2880e-06 - val_accuracy: 0.9464 - val_loss: 0.1997
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 334s 2s/step - accuracy: 1.0000 - loss: 6.9265e-06 - val_accuracy: 0.9464 - val_loss: 0.1995

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 94.64%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'ResNet101V2_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9556 - loss: 0.1753
# Test Accuracy: 94.43%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       1.00      0.99      0.99       100
#              Chickenpox       0.90      0.90      0.90       100
#                  Cowpox       0.95      0.96      0.96       100
#                    HFMD       0.94      0.96      0.95       100
#                 Healthy       0.95      0.96      0.96       100
#                 Measles       0.99      0.95      0.97       100
#               Monkeypox       0.88      0.89      0.89       100
#
#                accuracy                           0.94       700
#               macro avg       0.94      0.94      0.94       700
#            weighted avg       0.94      0.94      0.94       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.MobileNetV3Large(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='swish')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 62s 320ms/step - accuracy: 0.2290 - loss: 1.8987 - val_accuracy: 0.2455 - val_loss: 1.8097
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 55s 317ms/step - accuracy: 0.2952 - loss: 1.7527 - val_accuracy: 0.3542 - val_loss: 1.6789
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 59s 337ms/step - accuracy: 0.3507 - loss: 1.6670 - val_accuracy: 0.3423 - val_loss: 1.6897
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 64s 366ms/step - accuracy: 0.3994 - loss: 1.5981 - val_accuracy: 0.3497 - val_loss: 1.6505
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 63s 358ms/step - accuracy: 0.4121 - loss: 1.5502 - val_accuracy: 0.3854 - val_loss: 1.6534
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 62s 351ms/step - accuracy: 0.4134 - loss: 1.5246 - val_accuracy: 0.3512 - val_loss: 1.7412
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 63s 360ms/step - accuracy: 0.4199 - loss: 1.5139 - val_accuracy: 0.4033 - val_loss: 1.5438
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 64s 368ms/step - accuracy: 0.4586 - loss: 1.4472 - val_accuracy: 0.4315 - val_loss: 1.5427
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 71s 405ms/step - accuracy: 0.4660 - loss: 1.4243 - val_accuracy: 0.3571 - val_loss: 1.6288
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 78s 446ms/step - accuracy: 0.4631 - loss: 1.4191 - val_accuracy: 0.4420 - val_loss: 1.4863
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 68s 386ms/step - accuracy: 0.4691 - loss: 1.4200 - val_accuracy: 0.4494 - val_loss: 1.5398
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 65s 369ms/step - accuracy: 0.4866 - loss: 1.3864 - val_accuracy: 0.4137 - val_loss: 1.5509
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 61s 351ms/step - accuracy: 0.4863 - loss: 1.3622 - val_accuracy: 0.4375 - val_loss: 1.5010
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 61s 346ms/step - accuracy: 0.4988 - loss: 1.3345 - val_accuracy: 0.4241 - val_loss: 1.5542
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 58s 331ms/step - accuracy: 0.5130 - loss: 1.3167 - val_accuracy: 0.4792 - val_loss: 1.4376
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 64s 363ms/step - accuracy: 0.5121 - loss: 1.2931 - val_accuracy: 0.4182 - val_loss: 1.5884
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 65s 370ms/step - accuracy: 0.5085 - loss: 1.3321 - val_accuracy: 0.4807 - val_loss: 1.4606
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 69s 397ms/step - accuracy: 0.5116 - loss: 1.3022 - val_accuracy: 0.4420 - val_loss: 1.5022
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 74s 420ms/step - accuracy: 0.5252 - loss: 1.2686 - val_accuracy: 0.4896 - val_loss: 1.4889
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 70s 401ms/step - accuracy: 0.5216 - loss: 1.2785 - val_accuracy: 0.4762 - val_loss: 1.4313
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 70s 399ms/step - accuracy: 0.5354 - loss: 1.2249 - val_accuracy: 0.4464 - val_loss: 1.5626
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 382ms/step - accuracy: 0.5365 - loss: 1.2637 - val_accuracy: 0.4851 - val_loss: 1.4607
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 385ms/step - accuracy: 0.5573 - loss: 1.2242 - val_accuracy: 0.4315 - val_loss: 1.5526
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 68s 387ms/step - accuracy: 0.5533 - loss: 1.2131 - val_accuracy: 0.4821 - val_loss: 1.5191
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 383ms/step - accuracy: 0.5774 - loss: 1.1657 - val_accuracy: 0.4911 - val_loss: 1.4746
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 68s 385ms/step - accuracy: 0.5560 - loss: 1.1766 - val_accuracy: 0.4851 - val_loss: 1.4948
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 68s 387ms/step - accuracy: 0.5849 - loss: 1.1828 - val_accuracy: 0.5089 - val_loss: 1.4324
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 382ms/step - accuracy: 0.5774 - loss: 1.1682 - val_accuracy: 0.4807 - val_loss: 1.4645
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 68s 388ms/step - accuracy: 0.5508 - loss: 1.2006 - val_accuracy: 0.5193 - val_loss: 1.4540
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 382ms/step - accuracy: 0.5797 - loss: 1.1539 - val_accuracy: 0.5208 - val_loss: 1.4164
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 380ms/step - accuracy: 0.5819 - loss: 1.1338 - val_accuracy: 0.4866 - val_loss: 1.5161
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 381ms/step - accuracy: 0.5933 - loss: 1.1205 - val_accuracy: 0.4881 - val_loss: 1.4935
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 385ms/step - accuracy: 0.6105 - loss: 1.0827 - val_accuracy: 0.5104 - val_loss: 1.4610
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 381ms/step - accuracy: 0.5952 - loss: 1.1076 - val_accuracy: 0.4792 - val_loss: 1.5206
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 68s 387ms/step - accuracy: 0.6036 - loss: 1.0902 - val_accuracy: 0.5164 - val_loss: 1.5139
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 69s 392ms/step - accuracy: 0.6118 - loss: 1.0812 - val_accuracy: 0.5000 - val_loss: 1.4807
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 384ms/step - accuracy: 0.6190 - loss: 1.0510 - val_accuracy: 0.4821 - val_loss: 1.5181
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 381ms/step - accuracy: 0.6032 - loss: 1.0898 - val_accuracy: 0.3914 - val_loss: 1.7388
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 385ms/step - accuracy: 0.6060 - loss: 1.0999 - val_accuracy: 0.5119 - val_loss: 1.5040
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 381ms/step - accuracy: 0.6104 - loss: 1.0827 - val_accuracy: 0.4896 - val_loss: 1.5454
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 381ms/step - accuracy: 0.6147 - loss: 1.0683 - val_accuracy: 0.5551 - val_loss: 1.4484
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 67s 383ms/step - accuracy: 0.6127 - loss: 1.0477 - val_accuracy: 0.4940 - val_loss: 1.5569
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 68s 389ms/step - accuracy: 0.6238 - loss: 1.0623 - val_accuracy: 0.5119 - val_loss: 1.4978
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 69s 393ms/step - accuracy: 0.6158 - loss: 1.0521 - val_accuracy: 0.5149 - val_loss: 1.4597
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 69s 393ms/step - accuracy: 0.6363 - loss: 1.0145 - val_accuracy: 0.5298 - val_loss: 1.4712
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 59s 335ms/step - accuracy: 0.6414 - loss: 1.0001 - val_accuracy: 0.5402 - val_loss: 1.5211
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 55s 311ms/step - accuracy: 0.6456 - loss: 1.0079 - val_accuracy: 0.5298 - val_loss: 1.5306
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 54s 311ms/step - accuracy: 0.6307 - loss: 1.0242 - val_accuracy: 0.5387 - val_loss: 1.6179
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 56s 318ms/step - accuracy: 0.6286 - loss: 1.0373 - val_accuracy: 0.5357 - val_loss: 1.4894
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 56s 322ms/step - accuracy: 0.6231 - loss: 1.0383 - val_accuracy: 0.5417 - val_loss: 1.4958

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 54.17%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'MobileNetV3Large_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - accuracy: 0.6589 - loss: 1.0593
# Test Accuracy: 55.43%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 334ms/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       0.61      0.83      0.71       100
#              Chickenpox       0.45      0.48      0.46       100
#                  Cowpox       0.59      0.63      0.61       100
#                    HFMD       0.57      0.60      0.59       100
#                 Healthy       0.85      0.50      0.63       100
#                 Measles       0.46      0.72      0.56       100
#               Monkeypox       0.41      0.12      0.19       100
#
#                accuracy                           0.55       700
#               macro avg       0.56      0.55      0.53       700
#            weighted avg       0.56      0.55      0.53       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

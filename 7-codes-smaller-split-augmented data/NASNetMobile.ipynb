# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.NASNetMobile(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 121s 582ms/step - accuracy: 0.6466 - loss: 0.9866 - val_accuracy: 0.8467 - val_loss: 0.4572
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 78s 446ms/step - accuracy: 0.8644 - loss: 0.3834 - val_accuracy: 0.8646 - val_loss: 0.3886
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 484ms/step - accuracy: 0.9078 - loss: 0.2520 - val_accuracy: 0.8274 - val_loss: 0.4787
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 86s 491ms/step - accuracy: 0.9482 - loss: 0.1659 - val_accuracy: 0.8765 - val_loss: 0.3464
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 481ms/step - accuracy: 0.9724 - loss: 0.0933 - val_accuracy: 0.8929 - val_loss: 0.3249
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 479ms/step - accuracy: 0.9865 - loss: 0.0595 - val_accuracy: 0.8914 - val_loss: 0.3440
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 83s 476ms/step - accuracy: 0.9904 - loss: 0.0404 - val_accuracy: 0.8973 - val_loss: 0.3050
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 480ms/step - accuracy: 0.9951 - loss: 0.0230 - val_accuracy: 0.9048 - val_loss: 0.3515
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 481ms/step - accuracy: 0.9959 - loss: 0.0202 - val_accuracy: 0.9018 - val_loss: 0.3117
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 480ms/step - accuracy: 0.9990 - loss: 0.0111 - val_accuracy: 0.8958 - val_loss: 0.3570
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 87s 496ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.8973 - val_loss: 0.4094
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 487ms/step - accuracy: 0.9935 - loss: 0.0259 - val_accuracy: 0.8914 - val_loss: 0.3936
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 83s 476ms/step - accuracy: 0.9936 - loss: 0.0240 - val_accuracy: 0.8720 - val_loss: 0.4778
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 485ms/step - accuracy: 0.9748 - loss: 0.0802 - val_accuracy: 0.8943 - val_loss: 0.4282
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 480ms/step - accuracy: 0.9854 - loss: 0.0474 - val_accuracy: 0.8780 - val_loss: 0.4845
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 477ms/step - accuracy: 0.9834 - loss: 0.0579 - val_accuracy: 0.8795 - val_loss: 0.5187
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 83s 477ms/step - accuracy: 0.9931 - loss: 0.0191 - val_accuracy: 0.9033 - val_loss: 0.3950
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 484ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9062 - val_loss: 0.3683
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 88s 503ms/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 0.9092 - val_loss: 0.3537
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 86s 493ms/step - accuracy: 1.0000 - loss: 6.8531e-04 - val_accuracy: 0.9107 - val_loss: 0.3650
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 478ms/step - accuracy: 1.0000 - loss: 4.4130e-04 - val_accuracy: 0.9077 - val_loss: 0.3589
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 483ms/step - accuracy: 1.0000 - loss: 3.5809e-04 - val_accuracy: 0.9077 - val_loss: 0.3735
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 86s 494ms/step - accuracy: 1.0000 - loss: 3.1759e-04 - val_accuracy: 0.9107 - val_loss: 0.3705
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 481ms/step - accuracy: 1.0000 - loss: 2.8944e-04 - val_accuracy: 0.9107 - val_loss: 0.3715
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 479ms/step - accuracy: 1.0000 - loss: 2.4438e-04 - val_accuracy: 0.9092 - val_loss: 0.3776
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 486ms/step - accuracy: 1.0000 - loss: 2.2075e-04 - val_accuracy: 0.9077 - val_loss: 0.3791
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 480ms/step - accuracy: 1.0000 - loss: 1.9889e-04 - val_accuracy: 0.9092 - val_loss: 0.3824
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 83s 476ms/step - accuracy: 1.0000 - loss: 1.8024e-04 - val_accuracy: 0.9062 - val_loss: 0.3918
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 86s 489ms/step - accuracy: 1.0000 - loss: 1.9815e-04 - val_accuracy: 0.9077 - val_loss: 0.3879
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 88s 501ms/step - accuracy: 1.0000 - loss: 1.5480e-04 - val_accuracy: 0.9077 - val_loss: 0.3983
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 484ms/step - accuracy: 1.0000 - loss: 1.3897e-04 - val_accuracy: 0.9092 - val_loss: 0.3994
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 483ms/step - accuracy: 1.0000 - loss: 1.2673e-04 - val_accuracy: 0.9077 - val_loss: 0.3927
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 487ms/step - accuracy: 1.0000 - loss: 1.3095e-04 - val_accuracy: 0.9062 - val_loss: 0.3986
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 484ms/step - accuracy: 1.0000 - loss: 1.0929e-04 - val_accuracy: 0.9062 - val_loss: 0.4063
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 487ms/step - accuracy: 1.0000 - loss: 9.5526e-05 - val_accuracy: 0.9092 - val_loss: 0.4095
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 86s 489ms/step - accuracy: 1.0000 - loss: 9.1597e-05 - val_accuracy: 0.9077 - val_loss: 0.4067
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 486ms/step - accuracy: 1.0000 - loss: 8.3394e-05 - val_accuracy: 0.9092 - val_loss: 0.4081
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 86s 489ms/step - accuracy: 1.0000 - loss: 7.7483e-05 - val_accuracy: 0.9092 - val_loss: 0.4145
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 481ms/step - accuracy: 1.0000 - loss: 7.1064e-05 - val_accuracy: 0.9092 - val_loss: 0.4106
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 481ms/step - accuracy: 1.0000 - loss: 6.6959e-05 - val_accuracy: 0.9122 - val_loss: 0.4123
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 487ms/step - accuracy: 1.0000 - loss: 5.9375e-05 - val_accuracy: 0.9122 - val_loss: 0.4152
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 480ms/step - accuracy: 1.0000 - loss: 5.7743e-05 - val_accuracy: 0.9137 - val_loss: 0.4183
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 87s 498ms/step - accuracy: 1.0000 - loss: 5.3082e-05 - val_accuracy: 0.9077 - val_loss: 0.4208
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 87s 495ms/step - accuracy: 1.0000 - loss: 4.9278e-05 - val_accuracy: 0.9092 - val_loss: 0.4189
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 86s 493ms/step - accuracy: 1.0000 - loss: 4.5489e-05 - val_accuracy: 0.9107 - val_loss: 0.4219
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 485ms/step - accuracy: 1.0000 - loss: 4.0343e-05 - val_accuracy: 0.9077 - val_loss: 0.4286
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 485ms/step - accuracy: 1.0000 - loss: 3.7849e-05 - val_accuracy: 0.9122 - val_loss: 0.4246
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 86s 492ms/step - accuracy: 1.0000 - loss: 3.3220e-05 - val_accuracy: 0.9092 - val_loss: 0.4329
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 88s 505ms/step - accuracy: 1.0000 - loss: 3.3624e-05 - val_accuracy: 0.9122 - val_loss: 0.4330
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 89s 510ms/step - accuracy: 1.0000 - loss: 2.8270e-05 - val_accuracy: 0.9092 - val_loss: 0.4364

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 90.92%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'NASNetMobile_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 437ms/step - accuracy: 0.9334 - loss: 0.3387
# Test Accuracy: 89.86%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 665ms/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       0.95      0.98      0.97       100
#              Chickenpox       0.86      0.93      0.89       100
#                  Cowpox       0.92      0.92      0.92       100
#                    HFMD       0.86      0.81      0.84       100
#                 Healthy       0.90      0.97      0.93       100
#                 Measles       0.92      0.93      0.93       100
#               Monkeypox       0.87      0.75      0.81       100
#
#                accuracy                           0.90       700
#               macro avg       0.90      0.90      0.90       700
#            weighted avg       0.90      0.90      0.90       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

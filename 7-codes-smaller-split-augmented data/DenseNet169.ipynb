# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.DenseNet169(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# Epoch 1/50
# c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.6916 - loss: 0.9285 - val_accuracy: 0.8690 - val_loss: 0.3969
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.9212 - loss: 0.2342 - val_accuracy: 0.9167 - val_loss: 0.2489
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.9415 - loss: 0.1603 - val_accuracy: 0.9152 - val_loss: 0.2274
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.9704 - loss: 0.1000 - val_accuracy: 0.9301 - val_loss: 0.2143
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.9791 - loss: 0.0691 - val_accuracy: 0.9226 - val_loss: 0.2233
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.9824 - loss: 0.0553 - val_accuracy: 0.9479 - val_loss: 0.1553
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.9951 - loss: 0.0232 - val_accuracy: 0.9345 - val_loss: 0.1714
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - accuracy: 0.9958 - loss: 0.0173 - val_accuracy: 0.9360 - val_loss: 0.1645
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 264s 2s/step - accuracy: 0.9916 - loss: 0.0288 - val_accuracy: 0.9435 - val_loss: 0.1889
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.9970 - loss: 0.0109 - val_accuracy: 0.9568 - val_loss: 0.1515
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.9976 - loss: 0.0092 - val_accuracy: 0.9271 - val_loss: 0.2276
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.9608 - loss: 0.1118 - val_accuracy: 0.9152 - val_loss: 0.3374
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.9837 - loss: 0.0615 - val_accuracy: 0.9420 - val_loss: 0.1870
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.9952 - loss: 0.0193 - val_accuracy: 0.9435 - val_loss: 0.1920
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - accuracy: 0.9983 - loss: 0.0096 - val_accuracy: 0.9301 - val_loss: 0.2302
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.9899 - loss: 0.0288 - val_accuracy: 0.9509 - val_loss: 0.1606
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.9988 - loss: 0.0058 - val_accuracy: 0.9539 - val_loss: 0.1516
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9628 - val_loss: 0.1586
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 269s 2s/step - accuracy: 1.0000 - loss: 6.5485e-04 - val_accuracy: 0.9554 - val_loss: 0.1603
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 264s 2s/step - accuracy: 1.0000 - loss: 5.3564e-04 - val_accuracy: 0.9583 - val_loss: 0.1608
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 1.0000 - loss: 3.9783e-04 - val_accuracy: 0.9583 - val_loss: 0.1629
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 269s 2s/step - accuracy: 1.0000 - loss: 3.4028e-04 - val_accuracy: 0.9568 - val_loss: 0.1655
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 274s 2s/step - accuracy: 1.0000 - loss: 2.3950e-04 - val_accuracy: 0.9583 - val_loss: 0.1682
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 273s 2s/step - accuracy: 1.0000 - loss: 2.2658e-04 - val_accuracy: 0.9613 - val_loss: 0.1684
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 273s 2s/step - accuracy: 1.0000 - loss: 2.3193e-04 - val_accuracy: 0.9583 - val_loss: 0.1696
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 1.8911e-04 - val_accuracy: 0.9613 - val_loss: 0.1725
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 274s 2s/step - accuracy: 1.0000 - loss: 1.8259e-04 - val_accuracy: 0.9613 - val_loss: 0.1707
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 1.5783e-04 - val_accuracy: 0.9613 - val_loss: 0.1729
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 1.3720e-04 - val_accuracy: 0.9598 - val_loss: 0.1770
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 1.3082e-04 - val_accuracy: 0.9613 - val_loss: 0.1753
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 274s 2s/step - accuracy: 1.0000 - loss: 1.2049e-04 - val_accuracy: 0.9598 - val_loss: 0.1753
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 274s 2s/step - accuracy: 1.0000 - loss: 1.1100e-04 - val_accuracy: 0.9598 - val_loss: 0.1761
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 274s 2s/step - accuracy: 1.0000 - loss: 1.1113e-04 - val_accuracy: 0.9613 - val_loss: 0.1789
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 8.9470e-05 - val_accuracy: 0.9613 - val_loss: 0.1802
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 8.2293e-05 - val_accuracy: 0.9613 - val_loss: 0.1800
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 277s 2s/step - accuracy: 1.0000 - loss: 7.9201e-05 - val_accuracy: 0.9583 - val_loss: 0.1814
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 7.0975e-05 - val_accuracy: 0.9583 - val_loss: 0.1828
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 6.7508e-05 - val_accuracy: 0.9613 - val_loss: 0.1828
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 6.0528e-05 - val_accuracy: 0.9628 - val_loss: 0.1824
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 5.5946e-05 - val_accuracy: 0.9613 - val_loss: 0.1851
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 277s 2s/step - accuracy: 1.0000 - loss: 5.0877e-05 - val_accuracy: 0.9613 - val_loss: 0.1841
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 5.2674e-05 - val_accuracy: 0.9613 - val_loss: 0.1859
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 276s 2s/step - accuracy: 1.0000 - loss: 4.1592e-05 - val_accuracy: 0.9598 - val_loss: 0.1878
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 4.2179e-05 - val_accuracy: 0.9613 - val_loss: 0.1890
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 1.0000 - loss: 3.5320e-05 - val_accuracy: 0.9613 - val_loss: 0.1875
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 276s 2s/step - accuracy: 1.0000 - loss: 3.2426e-05 - val_accuracy: 0.9613 - val_loss: 0.1881
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 276s 2s/step - accuracy: 1.0000 - loss: 3.1385e-05 - val_accuracy: 0.9613 - val_loss: 0.1894
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 276s 2s/step - accuracy: 1.0000 - loss: 2.6044e-05 - val_accuracy: 0.9598 - val_loss: 0.1925
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 280s 2s/step - accuracy: 1.0000 - loss: 2.3939e-05 - val_accuracy: 0.9613 - val_loss: 0.1925
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 278s 2s/step - accuracy: 1.0000 - loss: 2.4265e-05 - val_accuracy: 0.9613 - val_loss: 0.1944

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 96.13%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'DenseNet169_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9682 - loss: 0.1908
# Test Accuracy: 95.14%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       1.00      1.00      1.00       100
#              Chickenpox       0.93      0.96      0.95       100
#                  Cowpox       0.98      0.94      0.96       100
#                    HFMD       0.96      0.93      0.94       100
#                 Healthy       0.92      0.98      0.95       100
#                 Measles       0.98      0.96      0.97       100
#               Monkeypox       0.89      0.89      0.89       100
#
#                accuracy                           0.95       700
#               macro avg       0.95      0.95      0.95       700
#            weighted avg       0.95      0.95      0.95       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

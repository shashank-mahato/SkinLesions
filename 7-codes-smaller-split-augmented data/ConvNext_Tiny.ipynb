# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
train_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\train'
val_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\val'
test_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-smaller-split-augmented data\test'
model_save_dir = r'C:\Users\Shashank Mahato\Desktop\Semester-8\Project Phase-2\7-codes-smaller-split-augmented data\Saved-models'

# Prepare the data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

# Load MobileNet model pre-trained on ImageNet
base_model = tf.keras.applications.ConvNeXtTiny(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Create new model on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure model save directory exists
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
# Out:
# Found 5600 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.
# WARNING:tensorflow:From c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\tensorflow\core.py:216: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
)
# Out:
# Epoch 1/50
# c:\Users\Shashank Mahato\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1469s 8s/step - accuracy: 0.2567 - loss: 1.8861 - val_accuracy: 0.3839 - val_loss: 1.5432
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1480s 8s/step - accuracy: 0.4023 - loss: 1.5615 - val_accuracy: 0.4405 - val_loss: 1.4617
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1483s 8s/step - accuracy: 0.4535 - loss: 1.4436 - val_accuracy: 0.5193 - val_loss: 1.3132
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1386s 8s/step - accuracy: 0.5120 - loss: 1.3110 - val_accuracy: 0.5238 - val_loss: 1.2334
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1361s 8s/step - accuracy: 0.5427 - loss: 1.2664 - val_accuracy: 0.5521 - val_loss: 1.1954
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1348s 8s/step - accuracy: 0.5486 - loss: 1.2067 - val_accuracy: 0.5685 - val_loss: 1.1556
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1341s 8s/step - accuracy: 0.5533 - loss: 1.1585 - val_accuracy: 0.6027 - val_loss: 1.1166
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1344s 8s/step - accuracy: 0.5926 - loss: 1.0951 - val_accuracy: 0.6235 - val_loss: 1.0498
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1341s 8s/step - accuracy: 0.6023 - loss: 1.0541 - val_accuracy: 0.5565 - val_loss: 1.1055
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1341s 8s/step - accuracy: 0.5998 - loss: 1.0421 - val_accuracy: 0.6280 - val_loss: 1.0322
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1342s 8s/step - accuracy: 0.6214 - loss: 1.0160 - val_accuracy: 0.6042 - val_loss: 1.0231
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1341s 8s/step - accuracy: 0.6223 - loss: 0.9874 - val_accuracy: 0.6086 - val_loss: 1.0318
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1337s 8s/step - accuracy: 0.6325 - loss: 0.9946 - val_accuracy: 0.6250 - val_loss: 1.0735
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1345s 8s/step - accuracy: 0.6329 - loss: 0.9842 - val_accuracy: 0.5923 - val_loss: 1.0495
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1338s 8s/step - accuracy: 0.6558 - loss: 0.9217 - val_accuracy: 0.6399 - val_loss: 0.9678
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1344s 8s/step - accuracy: 0.6320 - loss: 0.9609 - val_accuracy: 0.6429 - val_loss: 0.9628
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1337s 8s/step - accuracy: 0.6608 - loss: 0.9124 - val_accuracy: 0.6384 - val_loss: 0.9735
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1339s 8s/step - accuracy: 0.6614 - loss: 0.8933 - val_accuracy: 0.6250 - val_loss: 1.0547
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1340s 8s/step - accuracy: 0.6656 - loss: 0.8971 - val_accuracy: 0.5833 - val_loss: 1.0433
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1337s 8s/step - accuracy: 0.6653 - loss: 0.9068 - val_accuracy: 0.6607 - val_loss: 0.9479
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1334s 8s/step - accuracy: 0.6531 - loss: 0.9150 - val_accuracy: 0.6310 - val_loss: 0.9654
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1334s 8s/step - accuracy: 0.6804 - loss: 0.8515 - val_accuracy: 0.6503 - val_loss: 0.9306
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1330s 8s/step - accuracy: 0.7056 - loss: 0.8219 - val_accuracy: 0.6562 - val_loss: 0.9731
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1328s 8s/step - accuracy: 0.6899 - loss: 0.8229 - val_accuracy: 0.6652 - val_loss: 0.9412
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1313s 8s/step - accuracy: 0.6901 - loss: 0.8025 - val_accuracy: 0.6235 - val_loss: 0.9981
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1317s 8s/step - accuracy: 0.7024 - loss: 0.8070 - val_accuracy: 0.6518 - val_loss: 0.9404
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1332s 8s/step - accuracy: 0.6956 - loss: 0.7989 - val_accuracy: 0.6696 - val_loss: 0.9252
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1314s 8s/step - accuracy: 0.6995 - loss: 0.7914 - val_accuracy: 0.6533 - val_loss: 0.9248
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1313s 8s/step - accuracy: 0.7006 - loss: 0.7803 - val_accuracy: 0.6071 - val_loss: 1.0563
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1711s 10s/step - accuracy: 0.7059 - loss: 0.7783 - val_accuracy: 0.6354 - val_loss: 0.9844
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1324s 8s/step - accuracy: 0.7154 - loss: 0.7585 - val_accuracy: 0.6607 - val_loss: 0.9757
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1345s 8s/step - accuracy: 0.7111 - loss: 0.7757 - val_accuracy: 0.6711 - val_loss: 0.8899
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1342s 8s/step - accuracy: 0.7182 - loss: 0.7489 - val_accuracy: 0.6652 - val_loss: 0.9033
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1344s 8s/step - accuracy: 0.7051 - loss: 0.7695 - val_accuracy: 0.6503 - val_loss: 0.9958
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1369s 8s/step - accuracy: 0.7274 - loss: 0.7346 - val_accuracy: 0.6220 - val_loss: 0.9971
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1339s 8s/step - accuracy: 0.7203 - loss: 0.7563 - val_accuracy: 0.6592 - val_loss: 0.9162
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1341s 8s/step - accuracy: 0.7128 - loss: 0.7492 - val_accuracy: 0.6741 - val_loss: 0.8993
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1354s 8s/step - accuracy: 0.7225 - loss: 0.7002 - val_accuracy: 0.6711 - val_loss: 0.9006
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1360s 8s/step - accuracy: 0.7247 - loss: 0.7417 - val_accuracy: 0.7113 - val_loss: 0.9174
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1379s 8s/step - accuracy: 0.7204 - loss: 0.7293 - val_accuracy: 0.6756 - val_loss: 0.8768
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1375s 8s/step - accuracy: 0.7234 - loss: 0.7321 - val_accuracy: 0.6994 - val_loss: 0.8868
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1373s 8s/step - accuracy: 0.7242 - loss: 0.7140 - val_accuracy: 0.6905 - val_loss: 0.8905
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1377s 8s/step - accuracy: 0.7372 - loss: 0.6929 - val_accuracy: 0.6592 - val_loss: 0.9772
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1374s 8s/step - accuracy: 0.7383 - loss: 0.6945 - val_accuracy: 0.6310 - val_loss: 0.9874
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1378s 8s/step - accuracy: 0.7420 - loss: 0.6745 - val_accuracy: 0.6905 - val_loss: 0.8785
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1408s 8s/step - accuracy: 0.7435 - loss: 0.6894 - val_accuracy: 0.6696 - val_loss: 0.8847
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1566s 9s/step - accuracy: 0.7319 - loss: 0.6848 - val_accuracy: 0.6786 - val_loss: 0.9173
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1629s 9s/step - accuracy: 0.7501 - loss: 0.6661 - val_accuracy: 0.6860 - val_loss: 0.8637
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1641s 9s/step - accuracy: 0.7498 - loss: 0.6761 - val_accuracy: 0.6890 - val_loss: 0.8910
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1656s 9s/step - accuracy: 0.7487 - loss: 0.6719 - val_accuracy: 0.6905 - val_loss: 0.8762

# %%
final_val_accuracy = history.history['val_accuracy'][-1]
print(f'Final Validation Accuracy: {final_val_accuracy*100:.2f}%')
# Out:
# Final Validation Accuracy: 69.05%

# %%
# Save the model
model_save_path = os.path.join(model_save_dir, 'ConvNeXtTiny_model.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on test set
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Found 700 images belonging to 7 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 185s 8s/step - accuracy: 0.8050 - loss: 0.5887
# Test Accuracy: 65.14%

# %%
# Predict the data (for confusion matrix)
test_generator.reset()  # Ensure the generator is reset before prediction
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
class_labels = list(test_generator.class_indices.keys())

# Visualizing the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 187s 8s/step

# %%
# Classification Report
print('\nClassification Report')
report = classification_report(true_classes, predicted_classes, target_names=list(test_generator.class_indices.keys()))
print(report)
# Out:
# Classification Report
#                          precision    recall  f1-score   support
#
# Acne and Rosacea Photos       0.85      0.97      0.91       100
#              Chickenpox       0.37      0.85      0.52       100
#                  Cowpox       0.72      0.59      0.65       100
#                    HFMD       0.83      0.72      0.77       100
#                 Healthy       0.84      0.73      0.78       100
#                 Measles       0.65      0.49      0.56       100
#               Monkeypox       0.75      0.21      0.33       100
#
#                accuracy                           0.65       700
#               macro avg       0.72      0.65      0.64       700
#            weighted avg       0.72      0.65      0.64       700

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
